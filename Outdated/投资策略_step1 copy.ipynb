# %% [markdown]
# # 投资策略-step1

# %%
import pandas as pd
import yfinance as yf
import pandas_datareader.data as web
import requests
import io
import datetime
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_datareader.data as web
import requests
import io
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.tsa.arima.model import ARIMA
from keras.models import Sequential
from keras.layers import LSTM, Dense
import datetime

import numpy as np
import pandas as pd
import yfinance as yf
import pandas_datareader.data as web
import requests
import io
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from statsmodels.tsa.arima.model import ARIMA
from prophet import Prophet  # Use 'prophet' instead of 'fbprophet'
from keras.models import Sequential
from keras.layers import LSTM, Dense
import datetime
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf

# %%
# Import necessary libraries
import pandas as pd
import yfinance as yf
import pandas_datareader.data as web
import requests
import io
import datetime
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.arima.model import ARIMA
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler  # Important import for LSTM

# %%
import pandas as pd
import yfinance as yf
import datetime
from pandas_datareader import data as web

# Define the start and end dates
end = datetime.datetime.today()
start = end - datetime.timedelta(days=3*365)  # Approximate 3 years

# Define a function to fetch data from FRED
def fetch_fred_data(symbol):
    try:
        data = web.DataReader(symbol, 'fred', start, end)
        return data.resample('M').mean()  # Resample to monthly data
    except Exception as e:
        print(f"Error fetching {symbol} from FRED: {e}")
        return pd.DataFrame()

# Custom fetch for certain indicators that may not work through FRED
def fetch_custom_data(url):
    try:
        response = requests.get(url)
        data = pd.read_csv(io.StringIO(response.text), parse_dates=['DATE'], index_col='DATE')
        return data.resample('M').mean()  # Resample to monthly data
    except Exception as e:
        print(f"Error fetching custom data: {e}")
        return pd.DataFrame()

# URLs for custom data
urls = {
    'VIX': 'https://raw.githubusercontent.com/plotly/datasets/master/vix.csv',
}

# Retrieve data for the indicators
indicators = {
    'CPI': 'CPIAUCSL',  # Consumer Price Index
    'PPI': 'PPIACO',    # Producer Price Index
    'Federal Reserve Rate': 'FEDFUNDS',  # Federal Funds Rate
    'Treasury Yields': 'GS10',            # 10-Year Treasury Yield
    'NFP': 'PAYEMS',                      # Non-Farm Payrolls
    'Initial Jobless Claims': 'IC4WSA',  # Initial Jobless Claims
    'Consumer Confidence Index': 'UMCSENT',  # Consumer Confidence
    'Retail Sales Data': 'RSAFS',        # Retail Sales
    'PMI': 'IPMAN',                        # PMI
    'Housing Starts': 'HOUST',            # Housing Starts
    'VIX': '^VIX',                        # Volatility Index
    'PCE': 'PCE'                          # Personal Consumption Expenditures
}

# Create a dictionary to hold the data
data_frames = {}

# Fetch each indicator
for name, symbol in indicators.items():
    if symbol in urls:  # For custom URLs
        data = fetch_custom_data(urls[symbol])
    elif symbol.startswith('^'):  # For stock/market indices, use yfinance
        data = yf.download(symbol, start=start, end=end)['Close']
        data.index = pd.to_datetime(data.index)  # Ensure the index is a DatetimeIndex
        data = data.resample('M').mean()  # Resample to monthly
    else:  # For economic indicators, use FRED
        data = fetch_fred_data(symbol)

    if not data.empty:  # Only add non-empty DataFrames
        data_frames[name] = data

# Combine all data into a single DataFrame
combined_data = pd.concat(data_frames.values(), axis=1)
combined_data.columns = data_frames.keys()

# Display the combined DataFrame
print(combined_data.tail())
# Out:
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:60: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = data.resample('M').mean()  # Resample to monthly
#                 CPI      PPI  Federal Reserve Rate  Treasury Yields       NFP  \
# 2024-06-30  313.049  256.015                  5.33             4.31  158548.0
# 2024-07-31  313.534  257.485                  5.33             4.25  158692.0
# 2024-08-31  314.121  255.613                  5.33             3.87  158851.0
# 2024-09-30      NaN      NaN                  5.13             3.72  159105.0
# 2024-10-31      NaN      NaN                   NaN              NaN       NaN
#
#             Initial Jobless Claims  Consumer Confidence Index  \
# 2024-06-30                231500.0                       68.2
# 2024-07-31                235687.5                       66.4
# 2024-08-31                235200.0                       67.9
# 2024-09-30                227125.0                        NaN
# 2024-10-31                     NaN                        NaN
#
#             Retail Sales Data       PMI  Housing Starts        VIX      PCE
# 2024-06-30           702350.0   99.9546          1329.0  12.676842  19747.5
# 2024-07-31           710409.0   99.2452          1237.0  14.470000  19849.9
# 2024-08-31           710773.0  100.1903          1356.0  19.312273  19897.1
# 2024-09-30                NaN       NaN             NaN  17.769000      NaN
# 2024-10-31                NaN       NaN             NaN  20.301666      NaN
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3531231996.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   return data.resample('M').mean()  # Resample to monthly data

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# Fill NaNs with forward fill
combined_data.fillna(method='ffill', inplace=True)
combined_data.dropna(inplace=True)

# Prepare data for linear regression
X = np.arange(len(combined_data)).reshape(-1, 1)  # Time variable
forecasts = {}

# Linear Regression forecasts
for col in combined_data.columns:
    model = LinearRegression()
    model.fit(X, combined_data[col])
    future_X = np.arange(len(combined_data), len(combined_data) + 12).reshape(-1, 1)
    forecasts[col] = model.predict(future_X)

# Simple Moving Average function
def moving_average(data, window):
    return data.rolling(window=window).mean()

sma_forecasts = {}
# Calculate moving average forecasts
for col in combined_data.columns:
    sma_forecasts[col] = moving_average(combined_data[col], window=12).iloc[-1]  # Last SMA value

# Random Forest forecasts
rf_forecasts = {}
for col in combined_data.columns:
    model = RandomForestRegressor(n_estimators=100)
    model.fit(X, combined_data[col])
    rf_forecasts[col] = model.predict(future_X)

# Final Forecasting (excluding LSTM)
final_forecast = {}

# Assuming equal weights for simplicity
for col in combined_data.columns:
    final_forecast[col] = (forecasts[col] + sma_forecasts[col] + rf_forecasts[col]) / 3  # Exclude LSTM

# Convert to DataFrame for easier viewing
final_forecast_df = pd.DataFrame(final_forecast, index=pd.date_range(start=combined_data.index[-1] + pd.DateOffset(months=1), periods=12, freq='M'))

# Display the final forecast DataFrame
print(final_forecast_df)
# Out:
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/1939897321.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_data.fillna(method='ffill', inplace=True)
#                    CPI         PPI  Federal Reserve Rate  Treasury Yields  \
# 2024-11-30  315.145062  255.174715              5.783344         4.235558
# 2024-12-31  315.463884  255.126129              5.840995         4.258131
# 2025-01-31  315.782707  255.077542              5.898646         4.280704
# 2025-02-28  316.101529  255.028956              5.956298         4.303276
# 2025-03-31  316.420351  254.980370              6.013949         4.325849
# 2025-04-30  316.739173  254.931784              6.071600         4.348422
# 2025-05-31  317.057996  254.883197              6.129251         4.370994
# 2025-06-30  317.376818  254.834611              6.186902         4.393567
# 2025-07-31  317.695640  254.786025              6.244554         4.416140
# 2025-08-31  318.014463  254.737439              6.302205         4.438713
# 2025-09-30  318.333285  254.688852              6.359856         4.461285
# 2025-10-31  318.652107  254.640266              6.417507         4.483858
#
#                       NFP  Initial Jobless Claims  Consumer Confidence Index  \
# 2024-11-30  159164.407196           223764.460317                  70.111360
# 2024-12-31  159255.173090           223816.323788                  70.225766
# 2025-01-31  159345.938985           223868.187259                  70.340171
# 2025-02-28  159436.704879           223920.050729                  70.454577
# 2025-03-31  159527.470774           223971.914200                  70.568983
# 2025-04-30  159618.236668           224023.777671                  70.683389
# 2025-05-31  159709.002563           224075.641141                  70.797795
# 2025-06-30  159799.768457           224127.504612                  70.912201
# 2025-07-31  159890.534351           224179.368082                  71.026606
# 2025-08-31  159981.300246           224231.231553                  71.141012
# 2025-09-30  160072.066140           224283.095024                  71.255418
# 2025-10-31  160162.832035           224334.958494                  71.369824
#
#             Retail Sales Data        PMI  Housing Starts        VIX  \
# 2024-11-30      711455.651799  99.874704     1337.016190  15.766026
# 2024-12-31      712070.820225  99.869750     1333.612201  15.647876
# 2025-01-31      712685.988650  99.864797     1330.208211  15.529725
# 2025-02-28      713301.157076  99.859843     1326.804221  15.411575
# 2025-03-31      713916.325501  99.854890     1323.400232  15.293425
# 2025-04-30      714531.493927  99.849936     1319.996242  15.175274
# 2025-05-31      715146.662352  99.844983     1316.592252  15.057124
# 2025-06-30      715761.830778  99.840029     1313.188263  14.938973
# 2025-07-31      716376.999203  99.835076     1309.784273  14.820823
# 2025-08-31      716992.167629  99.830122     1306.380283  14.702673
# 2025-09-30      717607.336055  99.825168     1302.976293  14.584522
# 2025-10-31      718222.504480  99.820215     1299.572304  14.466372
#
#                      PCE
# 2024-11-30  19908.772772
# 2024-12-31  19938.389165
# 2025-01-31  19968.005557
# 2025-02-28  19997.621949
# 2025-03-31  20027.238341
# 2025-04-30  20056.854733
# 2025-05-31  20086.471125
# 2025-06-30  20116.087517
# 2025-07-31  20145.703909
# 2025-08-31  20175.320301
# 2025-09-30  20204.936694
# 2025-10-31  20234.553086
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/1939897321.py:45: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   final_forecast_df = pd.DataFrame(final_forecast, index=pd.date_range(start=combined_data.index[-1] + pd.DateOffset(months=1), periods=12, freq='M'))

# %%
# Define major industry indices symbols
industry_indices = {
    'S&P 500': '^GSPC',
    'Dow Jones': '^DJI',
    'NASDAQ': '^IXIC',
    'Russell 2000': '^RUT',
    'Financials': 'XLF',
    'Healthcare': 'XLV',
    'Technology': 'XLK',
    'Communication': 'XLC',
    'Consumer Staple': 'XLP',
    'Industrials': 'XLI',
    'Materials': 'XLB',
    'Real Estate': 'XLRE',
    'Energy':'XLE',
    'Utilities':'XLU',
    'Consumer Discretionary': 'XLY',
    'Gold':'GLD',
    'Long China' : 'MCHI',
    'Crude oil' : 'USO',
    'military': 'ITA'
}

# Fetch industry indices data
for name, symbol in industry_indices.items():
    data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
    if not data.empty:
        data_frames[name] = data

# Combine all data into a single DataFrame again
#industry_data = pd.concat(data_frames.values(), axis=1)
#industry_data.columns = data_frames.keys()

# Display the updated combined DataFrame
#print(industry_data.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()
# [*********************100%***********************]  1 of 1 completed
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/977304435.py:26: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data = yf.download(symbol, start=start, end=end)['Close'].resample('M').mean()

# %%
# Combine industry indices into the existing combined_data
for name, data in data_frames.items():
    combined_data[name] = data

# Drop NaNs by forward filling or interpolation
combined_data.fillna(method='ffill', inplace=True)
combined_data.dropna(inplace=True)
# Out:
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/929932855.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_data.fillna(method='ffill', inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Correlation matrix
corr_matrix = combined_data.corr()

# Plot heatmap using matplotlib
plt.figure(figsize=(12, 8))
plt.imshow(corr_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(corr_matrix.columns)), corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)), corr_matrix.columns)
plt.title('Correlation between Economic Indicators and Industry Indices')
plt.show()

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

industry_forecast_results = {}
X = combined_data[indicators.keys()]  # Economic indicators
for industry in industry_indices.keys():
    y = combined_data[industry]
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
    
    # Linear regression
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    # Store R^2 score
    r2 = r2_score(y_test, y_pred)
    industry_forecast_results[industry] = r2
    print(f"{industry} R^2 score: {r2}")

from statsmodels.tsa.seasonal import seasonal_decompose

for industry in industry_indices.keys():
    result = seasonal_decompose(combined_data[industry], model='multiplicative', period=12)
    result.plot()
    plt.title(f'{industry} Decomposition')
    plt.show()

from statsmodels.tsa.stattools import grangercausalitytests

for industry in industry_indices.keys():
    print(f"Granger Causality for {industry}")
    for indicator in indicators.keys():
        test = grangercausalitytests(combined_data[[indicator, industry]], maxlag=2, verbose=False)
        p_values = [round(test[i+1][0]['ssr_chi2test'][1], 4) for i in range(2)]
        print(f'{indicator}: p-values = {p_values}')


from sklearn.ensemble import RandomForestRegressor
import numpy as np

feature_importance_results = {}

for industry in industry_indices.keys():
    y = combined_data[industry]
    X = combined_data[indicators.keys()]
    
    # Train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)
    
    # Train Random Forest
    rf_model = RandomForestRegressor(n_estimators=100)
    rf_model.fit(X_train, y_train)
    
    # Get feature importance
    importances = rf_model.feature_importances_
    feature_importance_results[industry] = dict(zip(X.columns, importances))
    
    # Plot feature importances
    plt.figure(figsize=(10, 5))
    plt.bar(X.columns, importances)
    plt.title(f'Feature Importance for {industry}')
    plt.xticks(rotation=90)
    plt.show()

# Rank industries based on regression R² score and feature importance
ranked_industries = sorted(industry_forecast_results.items(), key=lambda x: x[1], reverse=True)

# Select top 3 industries
top_3_industries = [industry for industry, score in ranked_industries[:5]]
print(f"Top 3 promising industries: {top_3_industries}")
# Out:
# S&P 500 R^2 score: -8.975272248352399
# Dow Jones R^2 score: -19.33002417283899
# NASDAQ R^2 score: -1.1706654918643777
# Russell 2000 R^2 score: -19.237599309865747
# Financials R^2 score: -29.604946659343476
# Healthcare R^2 score: -38.26661992637461
# Technology R^2 score: 0.3390190522397968
# Communication R^2 score: 0.20251098161333791
# Consumer Staple R^2 score: -29.056172632193192
# Industrials R^2 score: -20.91291091611976
# Materials R^2 score: -83.01345350565335
# Real Estate R^2 score: -5.437052562656568
# Energy R^2 score: -60.00978549349417
# Utilities R^2 score: -6.539074096450077
# Consumer Discretionary R^2 score: -2.0380879907096574
# Gold R^2 score: -2.698742575394576
# Long China R^2 score: -0.6851678647853414
# Crude oil R^2 score: -0.004430443530555106
# military R^2 score: -6.456759381500927
# Granger Causality for S&P 500
# CPI: p-values = [np.float64(0.3644), np.float64(0.2049)]
# PPI: p-values = [np.float64(0.7803), np.float64(0.3625)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0558)]
# Treasury Yields: p-values = [np.float64(0.6482), np.float64(0.4838)]
# NFP: p-values = [np.float64(0.6996), np.float64(0.2595)]
# Initial Jobless Claims: p-values = [np.float64(0.2205), np.float64(0.5655)]
# Consumer Confidence Index: p-values = [np.float64(0.3571), np.float64(0.0019)]
# Retail Sales Data: p-values = [np.float64(0.3088), np.float64(0.0796)]
# PMI: p-values = [np.float64(0.3747), np.float64(0.0121)]
# Housing Starts: p-values = [np.float64(0.551), np.float64(0.9227)]
# VIX: p-values = [np.float64(0.0937), np.float64(0.0787)]
# PCE: p-values = [np.float64(0.9193), np.float64(0.8751)]
# Granger Causality for Dow Jones
# CPI: p-values = [np.float64(0.3127), np.float64(0.1666)]
# PPI: p-values = [np.float64(0.9059), np.float64(0.4296)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0331)]
# Treasury Yields: p-values = [np.float64(0.5642), np.float64(0.9495)]
# NFP: p-values = [np.float64(0.6001), np.float64(0.4158)]
# Initial Jobless Claims: p-values = [np.float64(0.2835), np.float64(0.5619)]
# Consumer Confidence Index: p-values = [np.float64(0.1429), np.float64(0.0177)]
# Retail Sales Data: p-values = [np.float64(0.3407), np.float64(0.0115)]
# PMI: p-values = [np.float64(0.2041), np.float64(0.0059)]
# Housing Starts: p-values = [np.float64(0.4517), np.float64(0.8815)]
# VIX: p-values = [np.float64(0.1412), np.float64(0.2654)]
# PCE: p-values = [np.float64(0.9242), np.float64(0.4274)]
# Granger Causality for NASDAQ
# CPI: p-values = [np.float64(0.4016), np.float64(0.1846)]
# PPI: p-values = [np.float64(0.7244), np.float64(0.2457)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0638)]
# Treasury Yields: p-values = [np.float64(0.6103), np.float64(0.4928)]
# NFP: p-values = [np.float64(0.7211), np.float64(0.2484)]
# Initial Jobless Claims: p-values = [np.float64(0.3164), np.float64(0.3153)]
# Consumer Confidence Index: p-values = [np.float64(0.2961), np.float64(0.001)]
# Retail Sales Data: p-values = [np.float64(0.4175), np.float64(0.1408)]
# PMI: p-values = [np.float64(0.362), np.float64(0.0701)]
# Housing Starts: p-values = [np.float64(0.8258), np.float64(0.9098)]
# VIX: p-values = [np.float64(0.0513), np.float64(0.0894)]
# PCE: p-values = [np.float64(0.8468), np.float64(0.9507)]
# Granger Causality for Russell 2000
# CPI: p-values = [np.float64(0.6943), np.float64(0.3734)]
# PPI: p-values = [np.float64(0.1717), np.float64(0.1118)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0109)]
# Treasury Yields: p-values = [np.float64(0.5496), np.float64(0.4546)]
# NFP: p-values = [np.float64(0.8458), np.float64(0.65)]
# Initial Jobless Claims: p-values = [np.float64(0.6682), np.float64(0.8113)]
# Consumer Confidence Index: p-values = [np.float64(0.7999), np.float64(0.001)]
# Retail Sales Data: p-values = [np.float64(0.6773), np.float64(0.0893)]
# PMI: p-values = [np.float64(0.6025), np.float64(0.1478)]
# Housing Starts: p-values = [np.float64(0.6439), np.float64(0.7121)]
# VIX: p-values = [np.float64(0.0005), np.float64(0.0013)]
# PCE: p-values = [np.float64(0.3413), np.float64(0.5571)]
# Granger Causality for Financials
# CPI: p-values = [np.float64(0.4597), np.float64(0.4624)]
# PPI: p-values = [np.float64(0.2502), np.float64(0.1485)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0361)]
# Treasury Yields: p-values = [np.float64(0.4119), np.float64(0.6266)]
# NFP: p-values = [np.float64(0.7322), np.float64(0.8785)]
# Initial Jobless Claims: p-values = [np.float64(0.7079), np.float64(0.7182)]
# Consumer Confidence Index: p-values = [np.float64(0.9397), np.float64(0.0416)]
# Retail Sales Data: p-values = [np.float64(0.6336), np.float64(0.0777)]
# PMI: p-values = [np.float64(0.6639), np.float64(0.0114)]
# Housing Starts: p-values = [np.float64(0.804), np.float64(0.8913)]
# VIX: p-values = [np.float64(0.0251), np.float64(0.038)]
# PCE: p-values = [np.float64(0.8447), np.float64(0.6198)]
# Granger Causality for Healthcare
# CPI: p-values = [np.float64(0.5406), np.float64(0.2702)]
# PPI: p-values = [np.float64(0.6761), np.float64(0.9077)]
# Federal Reserve Rate: p-values = [np.float64(0.0026), np.float64(0.3474)]
# Treasury Yields: p-values = [np.float64(0.7603), np.float64(0.8832)]
# NFP: p-values = [np.float64(0.8804), np.float64(0.4223)]
# Initial Jobless Claims: p-values = [np.float64(0.2165), np.float64(0.5706)]
# Consumer Confidence Index: p-values = [np.float64(0.5222), np.float64(0.1023)]
# Retail Sales Data: p-values = [np.float64(0.1784), np.float64(0.1223)]
# PMI: p-values = [np.float64(0.4966), np.float64(0.1496)]
# Housing Starts: p-values = [np.float64(0.2871), np.float64(0.5393)]
# VIX: p-values = [np.float64(0.1859), np.float64(0.2703)]
# PCE: p-values = [np.float64(0.832), np.float64(0.7979)]
# Granger Causality for Technology
# CPI: p-values = [np.float64(0.2462), np.float64(0.2028)]
# PPI: p-values = [np.float64(0.8028), np.float64(0.3081)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0606)]
# Treasury Yields: p-values = [np.float64(0.7325), np.float64(0.7865)]
# NFP: p-values = [np.float64(0.5485), np.float64(0.1483)]
# Initial Jobless Claims: p-values = [np.float64(0.1391), np.float64(0.2206)]
# Consumer Confidence Index: p-values = [np.float64(0.0793), np.float64(0.0009)]
# Retail Sales Data: p-values = [np.float64(0.1978), np.float64(0.0538)]
# PMI: p-values = [np.float64(0.1963), np.float64(0.0064)]
# Housing Starts: p-values = [np.float64(0.4594), np.float64(0.9092)]
# VIX: p-values = [np.float64(0.3295), np.float64(0.4237)]
# PCE: p-values = [np.float64(0.8265), np.float64(0.7997)]
# Granger Causality for Communication
# CPI: p-values = [np.float64(0.3748), np.float64(0.3386)]
# PPI: p-values = [np.float64(0.5719), np.float64(0.0278)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0187)]
# Treasury Yields: p-values = [np.float64(0.5306), np.float64(0.4682)]
# NFP: p-values = [np.float64(0.4731), np.float64(0.6977)]
# Initial Jobless Claims: p-values = [np.float64(0.3534), np.float64(0.262)]
# Consumer Confidence Index: p-values = [np.float64(0.4861), np.float64(0.0012)]
# Retail Sales Data: p-values = [np.float64(0.4713), np.float64(0.1935)]
# PMI: p-values = [np.float64(0.4535), np.float64(0.0696)]
# Housing Starts: p-values = [np.float64(0.9553), np.float64(0.9933)]
# VIX: p-values = [np.float64(0.117), np.float64(0.1272)]
# PCE: p-values = [np.float64(0.8672), np.float64(0.9389)]
# Granger Causality for Consumer Staple
# CPI: p-values = [np.float64(0.4653), np.float64(0.5206)]
# PPI: p-values = [np.float64(0.0227), np.float64(0.2488)]
# Federal Reserve Rate: p-values = [np.float64(0.0707), np.float64(0.2788)]
# Treasury Yields: p-values = [np.float64(0.8288), np.float64(0.6221)]
# NFP: p-values = [np.float64(0.8002), np.float64(0.6794)]
# Initial Jobless Claims: p-values = [np.float64(0.0757), np.float64(0.54)]
# Consumer Confidence Index: p-values = [np.float64(0.3649), np.float64(0.2714)]
# Retail Sales Data: p-values = [np.float64(0.1861), np.float64(0.1286)]
# PMI: p-values = [np.float64(0.4369), np.float64(0.0305)]
# Housing Starts: p-values = [np.float64(0.342), np.float64(0.6364)]
# VIX: p-values = [np.float64(0.0096), np.float64(0.0219)]
# PCE: p-values = [np.float64(0.8595), np.float64(0.8994)]
# Granger Causality for Industrials
# CPI: p-values = [np.float64(0.3699), np.float64(0.2821)]
# PPI: p-values = [np.float64(0.78), np.float64(0.4549)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0158)]
# Treasury Yields: p-values = [np.float64(0.761), np.float64(0.532)]
# NFP: p-values = [np.float64(0.731), np.float64(0.4856)]
# Initial Jobless Claims: p-values = [np.float64(0.1691), np.float64(0.4034)]
# Consumer Confidence Index: p-values = [np.float64(0.153), np.float64(0.0014)]
# Retail Sales Data: p-values = [np.float64(0.2588), np.float64(0.0109)]
# PMI: p-values = [np.float64(0.1937), np.float64(0.0219)]
# Housing Starts: p-values = [np.float64(0.2634), np.float64(0.6407)]
# VIX: p-values = [np.float64(0.3551), np.float64(0.5217)]
# PCE: p-values = [np.float64(0.9664), np.float64(0.6255)]
# Granger Causality for Materials
# CPI: p-values = [np.float64(0.2368), np.float64(0.3952)]
# PPI: p-values = [np.float64(0.0628), np.float64(0.7032)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0191)]
# Treasury Yields: p-values = [np.float64(0.6177), np.float64(0.3598)]
# NFP: p-values = [np.float64(0.7673), np.float64(0.1238)]
# Initial Jobless Claims: p-values = [np.float64(0.3512), np.float64(0.2461)]
# Consumer Confidence Index: p-values = [np.float64(0.5184), np.float64(0.181)]
# Retail Sales Data: p-values = [np.float64(0.6593), np.float64(0.0935)]
# PMI: p-values = [np.float64(0.4232), np.float64(0.0092)]
# Housing Starts: p-values = [np.float64(0.6487), np.float64(0.6761)]
# VIX: p-values = [np.float64(0.0158), np.float64(0.0359)]
# PCE: p-values = [np.float64(0.7839), np.float64(0.7286)]
# Granger Causality for Real Estate
# CPI: p-values = [np.float64(0.4115), np.float64(0.0492)]
# PPI: p-values = [np.float64(0.0002), np.float64(0.0)]
# Federal Reserve Rate: p-values = [np.float64(0.0), np.float64(0.0439)]
# Treasury Yields: p-values = [np.float64(0.8805), np.float64(0.6878)]
# NFP: p-values = [np.float64(0.6856), np.float64(0.2009)]
# Initial Jobless Claims: p-values = [np.float64(0.2128), np.float64(0.8159)]
# Consumer Confidence Index: p-values = [np.float64(0.2358), np.float64(0.0001)]
# Retail Sales Data: p-values = [np.float64(0.4935), np.float64(0.8784)]
# PMI: p-values = [np.float64(0.204), np.float64(0.0025)]
# Housing Starts: p-values = [np.float64(0.0936), np.float64(0.8489)]
# VIX: p-values = [np.float64(0.0), np.float64(0.0)]
# PCE: p-values = [np.float64(0.3753), np.float64(0.6994)]
# Granger Causality for Energy
# CPI: p-values = [np.float64(0.9668), np.float64(0.4481)]
# PPI: p-values = [np.float64(0.0577), np.float64(0.0125)]
# Federal Reserve Rate: p-values = [np.float64(0.0095), np.float64(0.1964)]
# Treasury Yields: p-values = [np.float64(0.399), np.float64(0.2066)]
# NFP: p-values = [np.float64(0.794), np.float64(0.8589)]
# Initial Jobless Claims: p-values = [np.float64(0.2795), np.float64(0.0543)]
# Consumer Confidence Index: p-values = [np.float64(0.9197), np.float64(0.0462)]
# Retail Sales Data: p-values = [np.float64(0.636), np.float64(0.411)]
# PMI: p-values = [np.float64(0.3097), np.float64(0.4155)]
# Housing Starts: p-values = [np.float64(0.0001), np.float64(0.0193)]
# VIX: p-values = [np.float64(0.0354), np.float64(0.0189)]
# PCE: p-values = [np.float64(0.9766), np.float64(0.6816)]
# Granger Causality for Utilities
# CPI: p-values = [np.float64(0.6211), np.float64(0.7357)]
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# /Users/chengyixu/Library/CloudStorage/OneDrive-Personal/个人投资 & 学习/IB Invest/final 2 copy/venv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:1556: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# Top 3 promising industries: ['Technology', 'Communication', 'Crude oil', 'Long China', 'NASDAQ']

# %% [markdown]
# https://stockanalysis.com/stocks/sector/technology/

# %% [markdown]
# https://www.sectorspdrs.com/mainfund/XLK

# %% [markdown]
# https://www.invesco.com/us/financial-products/etfs/holdings?audienceType=Institutional&ticker=PGJ

# %%
import pandas as pd

# Load the CSV file
file_path = 'portfolio-holdings-xlk.csv'

# Read the CSV file, assuming that the file has the columns starting from row 2
df = pd.read_csv(file_path, skiprows=1)

# Extract the 'Symbol' column and save it as a list
tickers = df['Symbol'].dropna().tolist()

# Display the list of tickers
tickers
# Out:
# ['AAPL',
#  'MSFT',
#  'NVDA',
#  'AVGO',
#  'CRM',
#  'AMD',
#  'ORCL',
#  'ACN',
#  'ADBE',
#  'CSCO',
#  'IBM',
#  'NOW',
#  'QCOM',
#  'TXN',
#  'INTU',
#  'AMAT',
#  'ADI',
#  'MU',
#  'PANW',
#  'LRCX',
#  'KLAC',
#  'ANET',
#  'INTC',
#  'PLTR',
#  'SNPS',
#  'MSI',
#  'APH',
#  'CDNS',
#  'CRWD',
#  'NXPI',
#  'ROP',
#  'ADSK',
#  'FTNT',
#  'FICO',
#  'MPWR',
#  'TEL',
#  'MCHP',
#  'IT',
#  'CTSH',
#  'HPQ',
#  'GLW',
#  'DELL',
#  'ON',
#  'CDW',
#  'ANSS',
#  'HPE',
#  'KEYS',
#  'NTAP',
#  'FSLR',
#  'TYL',
#  'STX',
#  'TER',
#  'PTC',
#  'GDDY',
#  'WDC',
#  'SMCI',
#  'TDY',
#  'ZBRA',
#  'VRSN',
#  'TRMB',
#  'AKAM',
#  'SWKS',
#  'GEN',
#  'ENPH',
#  'JBL',
#  'JNPR',
#  'FFIV',
#  'EPAM',
#  'QRVO']

# %%
# Defining the list of stock tickers in Python
tickers = [
    "AAPL", "NVDA", "MSFT", "AVGO", "CRM", "AMD", "ORCL", "ACN", "ADBE", "CSCO", "IBM", "NOW", "QCOM", 
    "TXN", "INTU", "AMAT", "PANW", "ADI", "MU", "LRCX", "KLAC", "ANET", "INTC", "PLTR", "SNPS", "APH", 
    "MSI", "CDNS", "CRWD", "NXPI", "ADSK", "ROP", "FTNT", "FICO", "MPWR", "TEL", "MCHP", "IT", "CTSH", 
    "HPQ", "DELL", "GLW", "ON", "CDW", "ANSS", "HPE", "KEYS", "NTAP", "TYL", "FSLR", "SMCI", "STX", 
    "GDDY", "WDC", "PTC", "TER", "TDY", "ZBRA", "VRSN", "SWKS", "AKAM", "TRMB", "GEN", "ENPH", "JBL", 
    "FFIV", "JNPR", "EPAM", "QRVO", "META", "GOOGL", "GOOG", "NFLX", "TMUS", "CMCSA", "DIS", "T", "VZ", 
    "TTWO", "EA", "CHTR", "OMC", "LYV", "WBD", "IPG", "NWSA", "MTCH", "FOXA", "PARA", "FOX", "NWS", 
    "XOM", "CVX", "COP", "EOG", "SLB", "WMB", "PSX", "OKE", "MPC", "KMI", "VLO", "HES", "BKR", "OXY", 
    "FANG", "TRGP", "HAL", "DVN", "EQT", "CTRA", "MRO", "APA", "AMZN", "TSLA", "COST", "PEP", "LIN", 
    "AMGN", "ISRG", "BKNG", "HON", "VRTX", "ADP", "SBUX", "REGN", "GILD", "PDD", "MELI", "MDLZ", "CEG", 
    "CTAS", "PYPL", "ASML", "MAR", "ORLY", "CSX", "MRVL", "ABNB", "DASH", "PCAR", "AEP", "CPRT", "WDAY", 
    "TTD", "PAYX", "KDP", "MNST", "ROST", "AZN", "KHC", "GEHC", "MCHP", "ODFL", "FAST", "EXC", "IDXX", 
    "DDOG", "VRSK", "EA", "BKR", "CTSH", "FANG", "CCEP", "XEL", "LULU", "ON", "CSGP", "CDW", "SMCI", 
    "DXCM", "ANSS", "TEAM", "BIIB", "TTWO", "ZS", "MRNA", "ILMN", "GFS", "MDB", "WBD", "ARM", "DLTR"
]

# %%
data = yf.download(tickers, period="5y")  # 5 years of data for earnings growth, etc.
# Out:
# [*********************100%***********************]  172 of 172 completed
#
# 2 Failed downloads:
# ['GEHC', 'ARM']: YFInvalidPeriodError("%ticker%: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']")

# %%
import yfinance as yf
import pandas as pd

# Sample list of tickers
# tickers = ['AAPL', 'AMD', 'AMZN', 'ARKK', 'ASML', 'AVGO', 'CRM', 'GOOG', 'INTC', 'JPM', 'META', 'MSFT', 'MU', 'NVDA', 'TSLA', 'TSM', 'UNG', 'VGT', 'XLF', 'XOM']

def check_200dma_cross(ticker):
    try:
        stock = yf.download(ticker, period="1y", interval="1d")
        
        # Check if the downloaded data is empty or insufficient
        if stock.empty or len(stock) < 200:
            print(f"Skipping {ticker}: Not enough data or data is empty.")
            return None
        
        stock['200DMA'] = stock['Close'].rolling(window=200).mean()
        
        # Avoid FutureWarning by using iloc to access the last elements by position
        if stock['Close'].iloc[-1] > stock['200DMA'].iloc[-1]:  # Price above 200DMA
            return ticker
        return None
    except Exception as e:
        print(f"Skipping {ticker}: {str(e)}")
        return None


selected_stocks = [check_200dma_cross(ticker) for ticker in tickers]
selected_stocks = list(filter(None, selected_stocks))

print("Stocks crossing 200-day moving average:", selected_stocks)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Stocks crossing 200-day moving average: ['AAPL', 'NVDA', 'AVGO', 'CRM', 'AMD', 'ORCL', 'ACN', 'CSCO', 'IBM', 'NOW', 'TXN', 'AMAT', 'PANW', 'ADI', 'KLAC', 'ANET', 'PLTR', 'APH', 'MSI', 'ADSK', 'FTNT', 'FICO', 'MPWR', 'TEL', 'IT', 'CTSH', 'HPQ', 'DELL', 'GLW', 'HPE', 'KEYS', 'NTAP', 'TYL', 'FSLR', 'STX', 'GDDY', 'WDC', 'TER', 'TDY', 'ZBRA', 'TRMB', 'GEN', 'JBL', 'FFIV', 'JNPR', 'META', 'GOOGL', 'GOOG', 'NFLX', 'TMUS', 'CMCSA', 'T', 'VZ', 'EA', 'CHTR', 'OMC', 'LYV', 'MTCH', 'FOXA', 'FOX', 'NWS', 'XOM', 'EOG', 'WMB', 'OKE', 'KMI', 'BKR', 'FANG', 'TRGP', 'EQT', 'MRO', 'AMZN', 'TSLA', 'COST', 'LIN', 'AMGN', 'ISRG', 'BKNG', 'HON', 'VRTX', 'ADP', 'SBUX', 'GILD', 'PDD', 'MELI', 'MDLZ', 'CEG', 'CTAS', 'PYPL', 'MAR', 'ORLY', 'MRVL', 'DASH', 'AEP', 'CPRT', 'TTD', 'PAYX', 'KDP', 'AZN', 'GEHC', 'FAST', 'EXC', 'DDOG', 'VRSK', 'EA', 'BKR', 'CTSH', 'FANG', 'CCEP', 'XEL', 'ILMN', 'ARM']

# %%
# Example stock list (tickers can be changed as needed)

# Downloading stock data
data = yf.download(tickers, period="5y")  # 5 years of data for earnings growth, etc.

def paul_tudor_jones_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock_data = data['Close'][ticker]
        ma_200 = stock_data.rolling(window=200).mean()
        
        if stock_data[-1] > ma_200[-1]:  # Latest price above the 200-day MA
            selected_stocks.append(ticker)
    
    return selected_stocks

# Select stocks based on this criterion
paul_tudor_jones_stocks = paul_tudor_jones_selection(data)
print("Paul Tudor Jones selected stocks:", paul_tudor_jones_stocks)
# Out:
# [*********************100%***********************]  172 of 172 completed
#
# 2 Failed downloads:
# ['GEHC', 'ARM']: YFInvalidPeriodError("%ticker%: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']")
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/1540280935.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if stock_data[-1] > ma_200[-1]:  # Latest price above the 200-day MA
# Paul Tudor Jones selected stocks: ['AAPL', 'NVDA', 'AVGO', 'CRM', 'AMD', 'ORCL', 'ACN', 'CSCO', 'IBM', 'NOW', 'TXN', 'AMAT', 'PANW', 'ADI', 'KLAC', 'ANET', 'PLTR', 'APH', 'MSI', 'ADSK', 'FTNT', 'FICO', 'MPWR', 'TEL', 'IT', 'CTSH', 'HPQ', 'DELL', 'GLW', 'HPE', 'KEYS', 'NTAP', 'TYL', 'FSLR', 'STX', 'GDDY', 'WDC', 'TER', 'TDY', 'ZBRA', 'TRMB', 'GEN', 'JBL', 'FFIV', 'JNPR', 'META', 'GOOGL', 'GOOG', 'NFLX', 'TMUS', 'CMCSA', 'T', 'VZ', 'EA', 'CHTR', 'OMC', 'LYV', 'MTCH', 'FOXA', 'FOX', 'NWS', 'XOM', 'EOG', 'WMB', 'OKE', 'KMI', 'BKR', 'FANG', 'TRGP', 'EQT', 'MRO', 'AMZN', 'TSLA', 'COST', 'LIN', 'AMGN', 'ISRG', 'BKNG', 'HON', 'VRTX', 'ADP', 'SBUX', 'GILD', 'PDD', 'MELI', 'MDLZ', 'CEG', 'CTAS', 'PYPL', 'MAR', 'ORLY', 'MRVL', 'DASH', 'AEP', 'CPRT', 'TTD', 'PAYX', 'KDP', 'AZN', 'FAST', 'EXC', 'DDOG', 'VRSK', 'EA', 'BKR', 'CTSH', 'FANG', 'CCEP', 'XEL', 'ILMN']

# %%
import yfinance as yf
import pandas as pd

def benjamin_graham_selection(data):
    selected_stocks = []
    tickers = data.columns.levels[1]  # Adjust this based on your data's structure
    
    for ticker in tickers:
        stock = yf.Ticker(ticker)
        try:
            # Fetch fundamental data
            pe_ratio = stock.info.get("trailingPE")
            pb_ratio = stock.info.get("priceToBook")
            currentRatio = stock.info.get("currentRatio")
            earnings_growth = stock.info.get("earningsGrowth")
            
            # Print the stats
            print(f"{ticker}: PE={pe_ratio}, PB={pb_ratio}, Current Ratio={currentRatio}, Earnings Growth={earnings_growth}")
            
            # Apply criteria
            if (pe_ratio is not None and pe_ratio <= 15 and
                pb_ratio is not None and pb_ratio <= 2 and
                currentRatio >= 1.5 and
                earnings_growth > 0):
                selected_stocks.append(ticker)
                
        except Exception as e:
            print(f"Error processing {ticker}: {e}")
    
    return selected_stocks

# Download historical data (price data doesn't include fundamental ratios)

# Select stocks based on Graham's criteria
benjamin_graham_stocks = benjamin_graham_selection(data)
print("Benjamin Graham selected stocks:", benjamin_graham_stocks)
# Out:
# AAPL: PE=34.41616, PB=51.522137, Current Ratio=0.953, Earnings Growth=0.111
# ABNB: PE=18.051771, PB=10.498376, Current Ratio=1.406, Earnings Growth=-0.125
# ACN: PE=31.474237, PB=7.9747734, Current Ratio=1.099, Earnings Growth=0.237
# ADBE: PE=42.089905, PB=15.182499, Current Ratio=1.111, Earnings Growth=0.233
# ADI: PE=69.30514, PB=3.236593, Current Ratio=1.687, Earnings Growth=-0.546
# ADP: PE=31.399342, PB=25.614288, Current Ratio=1.01, Earnings Growth=0.072
# ADSK: PE=56.25358, PB=23.905447, Current Ratio=0.636, Earnings Growth=0.262
# AEP: PE=19.64, PB=1.9987787, Current Ratio=0.655, Earnings Growth=-0.366
# AKAM: PE=25.143919, PB=3.2374837, Current Ratio=1.321, Earnings Growth=0.024
# AMAT: PE=22.570787, PB=8.790093, Current Ratio=2.86, Earnings Growth=0.108
# AMD: PE=205.7143, PB=4.9451966, Current Ratio=2.819, Earnings Growth=8.553
# AMGN: PE=54.67814, PB=28.80406, Current Ratio=1.264, Earnings Growth=-0.463
# AMZN: PE=43.608593, PB=8.106477, Current Ratio=1.096, Earnings Growth=0.938
# ANET: PE=52.044212, PB=14.910216, Current Ratio=4.553, Earnings Growth=0.342
# ANSS: PE=56.590828, PB=5.0185337, Current Ratio=2.951, Earnings Growth=0.85
# APA: PE=2.8419914, PB=1.7907802, Current Ratio=1.01, Earnings Growth=0.186
# APH: PE=38.291668, PB=8.623324, Current Ratio=2.017, Earnings Growth=0.108
# ARM: PE=350.24393, PB=26.57291, Current Ratio=3.606, Earnings Growth=1.1
# ASML: PE=43.84362, PB=22.03079, Current Ratio=1.516, Earnings Growth=-0.187
# AVGO: PE=145.75, PB=3.051789, Current Ratio=1.038, Earnings Growth=1.881
# AZN: PE=37.315536, PB=3.015456, Current Ratio=0.889, Earnings Growth=0.06
# BIIB: PE=22.959698, PB=1.671649, Current Ratio=2.287, Earnings Growth=-0.017
# BKNG: PE=29.687778, PB=None, Current Ratio=1.17, Earnings Growth=0.272
# BKR: PE=19.015228, PB=2.388269, Current Ratio=1.266, Earnings Growth=0.45
# CCEP: PE=20.083334, PB=4.164147, Current Ratio=0.847, Earnings Growth=-0.07
# CDNS: PE=69.987045, PB=17.36071, Current Ratio=1.432, Earnings Growth=0.037
# CDW: PE=27.403187, PB=13.736102, Current Ratio=1.135, Earnings Growth=0.078
# CEG: PE=37.152927, PB=7.659347, Current Ratio=1.354, Earnings Growth=0.008
# CHTR: PE=10.4501915, PB=3.6275575, Current Ratio=0.385, Earnings Growth=0.055
# CMCSA: PE=10.890958, PB=1.9099814, Current Ratio=0.664, Earnings Growth=-0.02
# COP: PE=12.3385315, PB=2.586549, Current Ratio=1.33, Earnings Growth=0.076
# COST: PE=53.639755, PB=16.70331, Current Ratio=0.966, Earnings Growth=0.088
# CPRT: PE=38.885715, PB=6.9678736, Current Ratio=7.029, Earnings Growth=-0.083
# CRM: PE=50.70783, PB=4.8465757, Current Ratio=1.041, Earnings Growth=0.148
# CRWD: PE=424.6522, PB=25.174845, Current Ratio=1.899, Earnings Growth=5.333
# CSCO: PE=20.759842, PB=4.648272, Current Ratio=0.908, Earnings Growth=-0.439
# CSGP: PE=144.51924, PB=4.159057, Current Ratio=9.27, Earnings Growth=-0.809
# CSX: PE=18.508196, PB=5.2051635, Current Ratio=1.161, Earnings Growth=0.006
# CTAS: PE=52.146095, PB=20.760128, Current Ratio=1.533, Earnings Growth=0.183
# CTRA: PE=14.1213875, PB=1.3875163, Current Ratio=1.404, Earnings Growth=0.074
# CTSH: PE=17.341686, PB=2.7224286, Current Ratio=2.459, Earnings Growth=0.251
# CVX: PE=14.742319, PB=1.7085133, Current Ratio=1.157, Earnings Growth=-0.241
# DASH: PE=None, PB=8.266036, Current Ratio=1.643, Earnings Growth=None
# DDOG: PE=263.23404, PB=17.308338, Current Ratio=2.006, Earnings Growth=None
# DELL: PE=22.454882, PB=None, Current Ratio=0.722, Earnings Growth=0.857
# DIS: PE=35.444447, PB=1.6695844, Current Ratio=0.716, Earnings Growth=None
# DLTR: PE=None, PB=2.0241218, Current Ratio=1.015, Earnings Growth=-0.323
# DVN: PE=7.5370703, PB=2.08546, Current Ratio=1.114, Earnings Growth=0.252
# DXCM: PE=43.12422, PB=11.428807, Current Ratio=2.815, Earnings Growth=0.266
# EA: PE=33.80425, PB=5.1352515, Current Ratio=1.453, Earnings Growth=-0.293
# ENPH: PE=112.01075, PB=15.945201, Current Ratio=4.232, Earnings Growth=-0.927
# EOG: PE=10.067182, PB=2.5455432, Current Ratio=2.118, Earnings Growth=0.109
# EPAM: PE=27.922747, PB=3.270771, Current Ratio=4.84, Earnings Growth=-0.163
# EQT: PE=24.228758, PB=1.0828415, Current Ratio=0.73, Earnings Growth=None
# EXC: PE=16.36777, PB=1.5153602, Current Ratio=1.034, Earnings Growth=0.316
# FANG: PE=10.034698, PB=1.9811668, Current Ratio=3.662, Earnings Growth=0.528
# FAST: PE=34.910446, PB=11.493857, Current Ratio=4.389, Earnings Growth=-0.019
# FFIV: PE=23.67961, PB=4.249458, Current Ratio=1.365, Earnings Growth=0.649
# FICO: PE=104.93565, PB=None, Current Ratio=1.872, Earnings Growth=-0.006
# FOX: PE=12.306709, PB=1.6585575, Current Ratio=2.541, Earnings Growth=-0.08
# FOXA: PE=13.284345, PB=1.7903122, Current Ratio=2.541, Earnings Growth=-0.08
# FSLR: PE=20.14643, PB=3.329104, Current Ratio=2.228, Earnings Growth=1.044
# FTNT: PE=46.023666, PB=206.31299, Current Ratio=1.321, Earnings Growth=0.485
# GDDY: PE=13.321131, PB=144.25224, Current Ratio=0.479, Earnings Growth=0.87
# GEHC: PE=26.210983, PB=5.3087864, Current Ratio=1.059, Earnings Growth=0.022
# GEN: PE=28.552084, PB=8.557602, Current Ratio=0.296, Earnings Growth=None
# GFS: PE=27.07534, PB=1.9385052, Current Ratio=2.216, Earnings Growth=-0.349
# GILD: PE=103.914635, PB=5.8076606, Current Ratio=1.142, Earnings Growth=0.554
# GLW: PE=87.43137, PB=3.4331691, Current Ratio=1.573, Earnings Growth=-0.636
# GOOG: PE=23.773315, PB=6.7887573, Current Ratio=2.079, Earnings Growth=0.314
# GOOGL: PE=23.550144, PB=6.7346773, Current Ratio=2.079, Earnings Growth=0.314
# HAL: PE=9.983389, PB=2.6534216, Current Ratio=2.13, Earnings Growth=0.182
# HES: PE=15.988358, PB=4.021787, Current Ratio=1.269, Earnings Growth=5.326
# HON: PE=23.630136, PB=7.935291, Current Ratio=1.206, Earnings Growth=0.063
# HPE: PE=14.87234, PB=1.2332392, Current Ratio=0.939, Earnings Growth=0.086
# HPQ: PE=12.631579, PB=None, Current Ratio=0.714, Earnings Growth=-0.145
# IBM: PE=25.233994, PB=8.765096, Current Ratio=1.123, Earnings Growth=0.141
# IDXX: PE=47.269382, PB=24.818893, Current Ratio=1.369, Earnings Growth=-0.086
# ILMN: PE=None, PB=15.464511, Current Ratio=1.114, Earnings Growth=None
# INTC: PE=97.166664, PB=0.86537033, Current Ratio=1.587, Earnings Growth=None
# INTU: PE=58.86468, PB=9.324567, Current Ratio=1.292, Earnings Growth=-0.185
# IPG: PE=11.433333, PB=3.0229144, Current Ratio=1.065, Earnings Growth=-0.162
# ISRG: PE=82.326195, PB=11.614006, Current Ratio=5.146, Earnings Growth=0.237
# IT: PE=48.91905, PB=61.559208, Current Ratio=0.898, Earnings Growth=0.181
# JBL: PE=11.042077, PB=8.173083, Current Ratio=1.086, Earnings Growth=0.019
# JNPR: PE=54.605637, PB=2.8013005, Current Ratio=1.685, Earnings Growth=0.429
# KDP: PE=23.20513, PB=1.98552, Current Ratio=0.509, Earnings Growth=0.058
# KEYS: PE=29.97688, PB=5.16174, Current Ratio=2.05, Earnings Growth=0.379
# KHC: PE=22.217949, PB=0.85700864, Current Ratio=1.006, Earnings Growth=-0.901
# KLAC: PE=38.711113, PB=31.284674, Current Ratio=2.152, Earnings Growth=0.245
# KMI: PE=21.394495, PB=1.7060502, Current Ratio=0.368, Earnings Growth=-0.009
# LIN: PE=35.80778, PB=5.871229, Current Ratio=0.951, Earnings Growth=0.078
# LRCX: PE=27.934483, PB=12.367939, Current Ratio=2.97, Earnings Growth=0.303
# LULU: PE=21.407894, PB=8.488261, Current Ratio=2.432, Earnings Growth=0.175
# LYV: PE=101.44545, PB=None, Current Ratio=0.919, Earnings Growth=0.009
# MAR: PE=25.70942, PB=None, Current Ratio=0.423, Earnings Growth=0.13
# MCHP: PE=30.800797, PB=6.4748745, Current Ratio=1.939, Earnings Growth=-0.802
# MDB: PE=None, PB=14.059824, Current Ratio=5.03, Earnings Growth=None
# MDLZ: PE=24.347078, PB=3.4215481, Current Ratio=0.676, Earnings Growth=-0.351
# MELI: PE=72.82104, PB=27.931192, Current Ratio=1.276, Earnings Growth=1.029
# META: PE=30.35791, PB=9.580048, Current Ratio=2.83, Earnings Growth=0.732
# MNST: PE=30.931252, PB=8.296731, Current Ratio=3.407, Earnings Growth=0.051
# MPC: PE=8.385221, PB=2.5584483, Current Ratio=1.306, Earnings Growth=-0.186
# MPWR: PE=110.29152, PB=20.472822, Current Ratio=6.767, Earnings Growth=0.005
# MRNA: PE=None, PB=1.9144262, Current Ratio=4.088, Earnings Growth=None
# MRO: PE=10.98047, PB=1.4022048, Current Ratio=0.572, Earnings Growth=0.319
# MRVL: PE=None, PB=4.4581985, Current Ratio=1.787, Earnings Growth=None
# MSFT: PE=35.144913, PB=11.48304, Current Ratio=1.275, Earnings Growth=0.097
# MSI: PE=53.6823, PB=95.23918, Current Ratio=1.2, Earnings Growth=0.209
# MTCH: PE=16.400002, PB=None, Current Ratio=2.51, Earnings Growth=0.017
# MU: PE=146.48572, PB=2.5197198, Current Ratio=2.635, Earnings Growth=None
# NFLX: PE=45.11, PB=14.007957, Current Ratio=0.948, Earnings Growth=0.483
# NOW: PE=166.72694, PB=21.901798, Current Ratio=1.118, Earnings Growth=-0.752
# NTAP: PE=24.765167, PB=27.923655, Current Ratio=0.958, Earnings Growth=0.696
# NVDA: PE=62.389668, PB=56.119087, Current Ratio=4.269, Earnings Growth=1.68
# NWS: PE=59.130436, PB=1.906364, Current Ratio=1.431, Earnings Growth=None
# NWSA: PE=56.326084, PB=1.8159518, Current Ratio=1.431, Earnings Growth=None
# NXPI: PE=22.020618, PB=6.6432934, Current Ratio=2.211, Earnings Growth=-0.049
# ODFL: PE=32.847866, PB=10.036037, Current Ratio=1.46, Earnings Growth=0.113
# OKE: PE=20.707964, PB=3.271812, Current Ratio=0.622, Earnings Growth=0.279
# OMC: PE=14.035962, PB=5.460905, Current Ratio=0.934, Earnings Growth=-0.093
# ON: PE=16.06606, PB=3.621566, Current Ratio=3.015, Earnings Growth=-0.393
# ORCL: PE=44.94072, PB=44.675888, Current Ratio=0.72, Earnings Growth=0.198
# ORLY: PE=29.38661, PB=None, Current Ratio=0.699, Earnings Growth=0.032
# OXY: PE=14.072539, PB=2.0697274, Current Ratio=1.041, Earnings Growth=0.635
# PANW: PE=48.848694, PB=22.33241, Current Ratio=0.892, Earnings Growth=0.591
# PARA: PE=None, PB=0.42453402, Current Ratio=1.297, Earnings Growth=None
# PAYX: PE=29.458422, PB=12.913356, Current Ratio=1.378, Earnings Growth=0.017
# PCAR: PE=10.901379, PB=3.0443926, Current Ratio=5.096, Earnings Growth=-0.086
# PDD: PE=15.136887, PB=0.7890709, Current Ratio=2.106, Earnings Growth=1.4
# PEP: PE=24.734398, PB=12.048073, Current Ratio=0.825, Earnings Growth=0.121
# PLTR: PE=243.82353, PB=22.900553, Current Ratio=5.916, Earnings Growth=5.0
# PSX: PE=11.349057, PB=1.880462, Current Ratio=1.145, Earnings Growth=-0.359
# PTC: PE=72.65306, PB=7.088245, Current Ratio=0.696, Earnings Growth=0.118
# PYPL: PE=19.69903, PB=4.0614524, Current Ratio=1.242, Earnings Growth=0.174
# QCOM: PE=21.298336, PB=7.5246534, Current Ratio=2.394, Earnings Growth=0.174
# QRVO: PE=None, PB=2.7350729, Current Ratio=1.955, Earnings Growth=None
# REGN: PE=26.615303, PB=3.845574, Current Ratio=5.439, Earnings Growth=0.46
# ROP: PE=40.545925, PB=3.208517, Current Ratio=0.531, Earnings Growth=-0.081
# ROST: PE=22.911148, PB=9.179289, Current Ratio=1.558, Earnings Growth=0.205
# SBUX: PE=26.94958, PB=None, Current Ratio=0.89, Earnings Growth=-0.061
# SLB: PE=14.424837, PB=2.9743934, Current Ratio=1.492, Earnings Growth=0.069
# SMCI: PE=22.56219, PB=4.86588, Current Ratio=3.767, Earnings Growth=0.61
# SNPS: PE=53.377323, PB=10.316616, Current Ratio=2.023, Earnings Growth=0.204
# STX: PE=68.76582, PB=None, Current Ratio=1.075, Earnings Growth=None
# SWKS: PE=19.863636, PB=2.4230664, Current Ratio=5.754, Earnings Growth=-0.385
# T: PE=12.563219, PB=1.4883912, Current Ratio=0.704, Earnings Growth=-0.197
# TDY: PE=24.007074, PB=2.222586, Current Ratio=1.979, Earnings Growth=-0.026
# TEAM: PE=None, PB=42.38648, Current Ratio=1.179, Earnings Growth=None
# TEL: PE=13.05814, PB=3.5185096, Current Ratio=1.507, Earnings Growth=0.114
# TER: PE=42.56579, PB=7.6672387, Current Ratio=2.804, Earnings Growth=0.562
# TMUS: PE=26.462406, PB=3.9336476, Current Ratio=0.838, Earnings Growth=0.339
# TRGP: PE=33.394516, PB=14.060223, Current Ratio=0.646, Earnings Growth=-0.076
# TRMB: PE=10.062193, PB=2.6749043, Current Ratio=0.994, Earnings Growth=28.705
# TSLA: PE=68.67978, PB=11.74916, Current Ratio=1.911, Earnings Growth=-0.462
# TTD: PE=224.56863, PB=23.406906, Current Ratio=1.796, Earnings Growth=1.521
# TTWO: PE=None, PB=4.4721913, Current Ratio=0.899, Earnings Growth=None
# TXN: PE=34.98443, PB=10.725045, Current Ratio=4.616, Earnings Growth=-0.348
# TYL: PE=122.96067, PB=8.082252, Current Ratio=1.056, Earnings Growth=0.365
# VLO: PE=7.7246456, PB=1.7168257, Current Ratio=1.48, Earnings Growth=-0.499
# VRSK: PE=43.765274, PB=90.13908, Current Ratio=0.953, Earnings Growth=0.583
# VRSN: PE=22.255703, PB=None, Current Ratio=0.639, Earnings Growth=0.125
# VRTX: PE=None, PB=8.014599, Current Ratio=2.521, Earnings Growth=None
# VZ: PE=16.54511, PB=1.9263765, Current Ratio=0.626, Earnings Growth=-0.009
# WBD: PE=None, PB=0.550917, Current Ratio=0.756, Earnings Growth=None
# WDAY: PE=41.35924, PB=7.6332397, Current Ratio=2.039, Earnings Growth=0.661
# WDC: PE=None, PB=2.0980372, Current Ratio=1.324, Earnings Growth=None
# WMB: PE=21.094828, PB=4.8657784, Current Ratio=0.45, Earnings Growth=-0.129
# XEL: PE=18.785076, PB=1.9534985, Current Ratio=0.966, Earnings Growth=0.038
# XOM: PE=14.598086, PB=2.020095, Current Ratio=1.36, Earnings Growth=0.104
# ZBRA: PE=82.7287, PB=5.7887635, Current Ratio=1.283, Earnings Growth=-0.219
# ZS: PE=None, PB=21.17654, Current Ratio=1.091, Earnings Growth=None
# Benjamin Graham selected stocks: ['FANG']

# %%
import yfinance as yf

def goldman_sachs_selection(tickers):
    selected_stocks = []
    
    for ticker in tickers:
        stock = yf.Ticker(ticker)
        pe_ratio = stock.info.get("trailingPE", None)
        pb_ratio = stock.info.get("priceToBook", None)
        earnings_growth = stock.info.get("earningsGrowth", None)
        
        # Convert to float if they are strings
        try:
            pe_ratio = float(pe_ratio) if pe_ratio is not None else None
            pb_ratio = float(pb_ratio) if pb_ratio is not None else None
            earnings_growth = float(earnings_growth) if earnings_growth is not None else None
        except ValueError:
            continue  # Skip this stock if conversion fails
        
        # Apply criteria (focus on value and earnings growth)
        if (pe_ratio is not None and pe_ratio <= 12 and
            pb_ratio is not None and pb_ratio <= 1.5 and
            earnings_growth is not None and earnings_growth > 0):
            selected_stocks.append(ticker)
    
    return selected_stocks

# Select stocks based on Goldman Sachs' criteria
goldman_sachs_stocks = goldman_sachs_selection(tickers)
print("Goldman Sachs selected stocks:", goldman_sachs_stocks)
# Out:
# Goldman Sachs selected stocks: ['MRO']

# %%
import numpy as np  # Make sure to import numpy for sqrt function

def bridgewater_risk_reward(ticker):
    stock = yf.download(ticker, period="1y", interval="1d")
    stock['Returns'] = stock['Close'].pct_change()
    mean_return = stock['Returns'].mean()
    std_dev = stock['Returns'].std()

    # Annualize the mean return and std dev
    annualized_return = mean_return * 252
    annualized_std_dev = std_dev * np.sqrt(252)

    # Sharpe Ratio
    sharpe_ratio = annualized_return / annualized_std_dev if annualized_std_dev > 0 else 0

    if sharpe_ratio > 0.5:  # Adjust threshold if necessary
        return ticker
    return None

bridgewater_stocks = [bridgewater_risk_reward(ticker) for ticker in tickers]
bridgewater_stocks = list(filter(None, bridgewater_stocks))

print("Stocks meeting Bridgewater's risk-reward criteria:", bridgewater_stocks)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Stocks meeting Bridgewater's risk-reward criteria: ['AAPL', 'NVDA', 'MSFT', 'AVGO', 'CRM', 'AMD', 'ORCL', 'ACN', 'IBM', 'NOW', 'QCOM', 'TXN', 'INTU', 'AMAT', 'PANW', 'ADI', 'MU', 'LRCX', 'KLAC', 'ANET', 'PLTR', 'APH', 'MSI', 'CRWD', 'NXPI', 'ADSK', 'ROP', 'FTNT', 'FICO', 'MPWR', 'TEL', 'IT', 'CTSH', 'HPQ', 'DELL', 'GLW', 'HPE', 'KEYS', 'NTAP', 'TYL', 'FSLR', 'SMCI', 'STX', 'GDDY', 'WDC', 'PTC', 'TER', 'ZBRA', 'TRMB', 'GEN', 'FFIV', 'JNPR', 'META', 'GOOGL', 'GOOG', 'NFLX', 'TMUS', 'T', 'VZ', 'EA', 'OMC', 'LYV', 'NWSA', 'FOXA', 'FOX', 'NWS', 'XOM', 'WMB', 'PSX', 'OKE', 'KMI', 'FANG', 'TRGP', 'AMZN', 'COST', 'LIN', 'AMGN', 'ISRG', 'BKNG', 'HON', 'VRTX', 'ADP', 'REGN', 'GILD', 'PDD', 'MELI', 'MDLZ', 'CEG', 'CTAS', 'PYPL', 'ASML', 'MAR', 'ORLY', 'CSX', 'MRVL', 'DASH', 'PCAR', 'AEP', 'CPRT', 'TTD', 'PAYX', 'KDP', 'ROST', 'AZN', 'GEHC', 'FAST', 'DDOG', 'VRSK', 'EA', 'CTSH', 'FANG', 'CCEP', 'XEL', 'SMCI', 'ARM']

# %%
import yfinance as yf

def ark_invest_selection(tickers):
    selected_stocks = []
    
    for ticker in tickers:
        stock = yf.Ticker(ticker)
        stock_info = stock.info
        
        earnings_growth = stock_info.get("earningsGrowth")
        return_on_equity = stock_info.get("returnOnEquity")
        rd_spending = stock_info.get("researchAndDevelopment")  # Corrected key
        
        # Debugging statements
        print(f"Ticker: {ticker}")
        print(f"Earnings Growth: {earnings_growth}")
        print(f"Return on Equity: {return_on_equity}")
        print(f"R&D Spending: {rd_spending}\n")
        
        # Selection criteria based on earnings growth, return on equity, and R&D spending
        if (earnings_growth is not None and earnings_growth >= 0.05 and
                return_on_equity is not None and return_on_equity >= 0.1 
                #and
                #rd_spending is not None and rd_spending > 0
                ):
            selected_stocks.append(ticker)

    return selected_stocks

# Ensure 'tickers' is a list of stock tickers
ark_invest_stocks = ark_invest_selection(tickers)

print("ARK Invest selected stocks:", ark_invest_stocks)
# Out:
# Ticker: AAPL
# Earnings Growth: 0.111
# Return on Equity: 1.60583
# R&D Spending: None
#
# Ticker: NVDA
# Earnings Growth: 1.68
# Return on Equity: 1.23767
# R&D Spending: None
#
# Ticker: MSFT
# Earnings Growth: 0.097
# Return on Equity: 0.37133
# R&D Spending: None
#
# Ticker: AVGO
# Earnings Growth: 1.881
# Return on Equity: 0.12509
# R&D Spending: None
#
# Ticker: CRM
# Earnings Growth: 0.148
# Return on Equity: 0.09734
# R&D Spending: None
#
# Ticker: AMD
# Earnings Growth: 8.553
# Return on Equity: 0.024249999
# R&D Spending: None
#
# Ticker: ORCL
# Earnings Growth: 0.198
# Return on Equity: 1.55578
# R&D Spending: None
#
# Ticker: ACN
# Earnings Growth: 0.237
# Return on Equity: 0.26674998
# R&D Spending: None
#
# Ticker: ADBE
# Earnings Growth: 0.233
# Return on Equity: 0.35355
# R&D Spending: None
#
# Ticker: CSCO
# Earnings Growth: -0.439
# Return on Equity: 0.22982
# R&D Spending: None
#
# Ticker: IBM
# Earnings Growth: 0.141
# Return on Equity: 0.36244
# R&D Spending: None
#
# Ticker: NOW
# Earnings Growth: -0.752
# Return on Equity: 0.147
# R&D Spending: None
#
# Ticker: QCOM
# Earnings Growth: 0.174
# Return on Equity: 0.38924
# R&D Spending: None
#
# Ticker: TXN
# Earnings Growth: -0.348
# Return on Equity: 0.32044
# R&D Spending: None
#
# Ticker: INTU
# Earnings Growth: -0.185
# Return on Equity: 0.16597
# R&D Spending: None
#
# Ticker: AMAT
# Earnings Growth: 0.108
# Return on Equity: 0.4391
# R&D Spending: None
#
# Ticker: PANW
# Earnings Growth: 0.591
# Return on Equity: 0.74517995
# R&D Spending: None
#
# Ticker: ADI
# Earnings Growth: -0.546
# Return on Equity: 0.04658
# R&D Spending: None
#
# Ticker: MU
# Earnings Growth: None
# Return on Equity: 0.01743
# R&D Spending: None
#
# Ticker: LRCX
# Earnings Growth: 0.303
# Return on Equity: 0.45706
# R&D Spending: None
#
# Ticker: KLAC
# Earnings Growth: 0.245
# Return on Equity: 0.87845004
# R&D Spending: None
#
# Ticker: ANET
# Earnings Growth: 0.342
# Return on Equity: 0.34463
# R&D Spending: None
#
# Ticker: INTC
# Earnings Growth: None
# Return on Equity: 0.00782
# R&D Spending: None
#
# Ticker: PLTR
# Earnings Growth: 5.0
# Return on Equity: 0.114870004
# R&D Spending: None
#
# Ticker: SNPS
# Earnings Growth: 0.204
# Return on Equity: 0.21819
# R&D Spending: None
#
# Ticker: APH
# Earnings Growth: 0.108
# Return on Equity: 0.25456
# R&D Spending: None
#
# Ticker: MSI
# Earnings Growth: 0.209
# Return on Equity: 2.51541
# R&D Spending: None
#
# Ticker: CDNS
# Earnings Growth: 0.037
# Return on Equity: 0.29442
# R&D Spending: None
#
# Ticker: CRWD
# Earnings Growth: 5.333
# Return on Equity: 0.07334
# R&D Spending: None
#
# Ticker: NXPI
# Earnings Growth: -0.049
# Return on Equity: 0.31456
# R&D Spending: None
#
# Ticker: ADSK
# Earnings Growth: 0.262
# Return on Equity: 0.57445997
# R&D Spending: None
#
# Ticker: ROP
# Earnings Growth: -0.081
# Return on Equity: 0.082679994
# R&D Spending: None
#
# Ticker: FTNT
# Earnings Growth: 0.485
# Return on Equity: 4.30883
# R&D Spending: None
#
# Ticker: FICO
# Earnings Growth: -0.006
# Return on Equity: None
# R&D Spending: None
#
# Ticker: MPWR
# Earnings Growth: 0.005
# Return on Equity: 0.20371
# R&D Spending: None
#
# Ticker: TEL
# Earnings Growth: 0.114
# Return on Equity: 0.28673
# R&D Spending: None
#
# Ticker: MCHP
# Earnings Growth: -0.802
# Return on Equity: 0.20696
# R&D Spending: None
#
# Ticker: IT
# Earnings Growth: 0.181
# Return on Equity: 1.34407
# R&D Spending: None
#
# Ticker: CTSH
# Earnings Growth: 0.251
# Return on Equity: 0.16379999
# R&D Spending: None
#
# Ticker: HPQ
# Earnings Growth: -0.145
# Return on Equity: None
# R&D Spending: None
#
# Ticker: DELL
# Earnings Growth: 0.857
# Return on Equity: None
# R&D Spending: None
#
# Ticker: GLW
# Earnings Growth: -0.636
# Return on Equity: 0.044260003
# R&D Spending: None
#
# Ticker: ON
# Earnings Growth: -0.393
# Return on Equity: 0.25236
# R&D Spending: None
#
# Ticker: CDW
# Earnings Growth: 0.078
# Return on Equity: 0.58541
# R&D Spending: None
#
# Ticker: ANSS
# Earnings Growth: 0.85
# Return on Equity: 0.094289996
# R&D Spending: None
#
# Ticker: HPE
# Earnings Growth: 0.086
# Return on Equity: 0.086660005
# R&D Spending: None
#
# Ticker: KEYS
# Earnings Growth: 0.379
# Return on Equity: 0.18031
# R&D Spending: None
#
# Ticker: NTAP
# Earnings Growth: 0.696
# Return on Equity: 1.2042199
# R&D Spending: None
#
# Ticker: TYL
# Earnings Growth: 0.365
# Return on Equity: 0.07044
# R&D Spending: None
#
# Ticker: FSLR
# Earnings Growth: 1.044
# Return on Equity: 0.18106002
# R&D Spending: None
#
# Ticker: SMCI
# Earnings Growth: 0.61
# Return on Equity: 0.32469
# R&D Spending: None
#
# Ticker: STX
# Earnings Growth: None
# Return on Equity: None
# R&D Spending: None
#
# Ticker: GDDY
# Earnings Growth: 0.87
# Return on Equity: None
# R&D Spending: None
#
# Ticker: WDC
# Earnings Growth: None
# Return on Equity: -0.06973
# R&D Spending: None
#
# Ticker: PTC
# Earnings Growth: 0.118
# Return on Equity: 0.10524999
# R&D Spending: None
#
# Ticker: TER
# Earnings Growth: 0.562
# Return on Equity: 0.1919
# R&D Spending: None
#
# Ticker: TDY
# Earnings Growth: -0.026
# Return on Equity: 0.09847
# R&D Spending: None
#
# Ticker: ZBRA
# Earnings Growth: -0.219
# Return on Equity: 0.07326
# R&D Spending: None
#
# Ticker: VRSN
# Earnings Growth: 0.125
# Return on Equity: None
# R&D Spending: None
#
# Ticker: SWKS
# Earnings Growth: -0.385
# Return on Equity: 0.12777
# R&D Spending: None
#
# Ticker: AKAM
# Earnings Growth: 0.024
# Return on Equity: 0.13906
# R&D Spending: None
#
# Ticker: TRMB
# Earnings Growth: 28.705
# Return on Equity: 0.30337
# R&D Spending: None
#
# Ticker: GEN
# Earnings Growth: None
# Return on Equity: 0.28326
# R&D Spending: None
#
# Ticker: ENPH
# Earnings Growth: -0.927
# Return on Equity: 0.13958
# R&D Spending: None
#
# Ticker: JBL
# Earnings Growth: 0.019
# Return on Equity: 0.60295
# R&D Spending: None
#
# Ticker: FFIV
# Earnings Growth: 0.649
# Return on Equity: 0.19534001
# R&D Spending: None
#
# Ticker: JNPR
# Earnings Growth: 0.429
# Return on Equity: 0.05277
# R&D Spending: None
#
# Ticker: EPAM
# Earnings Growth: -0.163
# Return on Equity: 0.12299
# R&D Spending: None
#
# Ticker: QRVO
# Earnings Growth: None
# Return on Equity: -0.00721
# R&D Spending: None
#
# Ticker: META
# Earnings Growth: 0.732
# Return on Equity: 0.35375
# R&D Spending: None
#
# Ticker: GOOGL
# Earnings Growth: 0.314
# Return on Equity: 0.30871
# R&D Spending: None
#
# Ticker: GOOG
# Earnings Growth: 0.314
# Return on Equity: 0.30871
# R&D Spending: None
#
# Ticker: NFLX
# Earnings Growth: 0.483
# Return on Equity: 0.31570998
# R&D Spending: None
#
# Ticker: TMUS
# Earnings Growth: 0.339
# Return on Equity: 0.14729
# R&D Spending: None
#
# Ticker: CMCSA
# Earnings Growth: -0.02
# Return on Equity: 0.17489
# R&D Spending: None
#
# Ticker: DIS
# Earnings Growth: None
# Return on Equity: 0.0546
# R&D Spending: None
#
# Ticker: T
# Earnings Growth: -0.197
# Return on Equity: 0.11788
# R&D Spending: None
#
# Ticker: VZ
# Earnings Growth: -0.009
# Return on Equity: 0.120950006
# R&D Spending: None
#
# Ticker: TTWO
# Earnings Growth: None
# Return on Equity: -0.50901
# R&D Spending: None
#
# Ticker: EA
# Earnings Growth: -0.293
# Return on Equity: 0.15624
# R&D Spending: None
#
# Ticker: CHTR
# Earnings Growth: 0.055
# Return on Equity: 0.34924
# R&D Spending: None
#
# Ticker: OMC
# Earnings Growth: -0.093
# Return on Equity: 0.35424
# R&D Spending: None
#
# Ticker: LYV
# Earnings Growth: 0.009
# Return on Equity: 0.52389
# R&D Spending: None
#
# Ticker: WBD
# Earnings Growth: None
# Return on Equity: -0.28667
# R&D Spending: None
#
# Ticker: IPG
# Earnings Growth: -0.162
# Return on Equity: 0.27183
# R&D Spending: None
#
# Ticker: NWSA
# Earnings Growth: None
# Return on Equity: 0.03943
# R&D Spending: None
#
# Ticker: MTCH
# Earnings Growth: 0.017
# Return on Equity: None
# R&D Spending: None
#
# Ticker: FOXA
# Earnings Growth: -0.08
# Return on Equity: 0.14313
# R&D Spending: None
#
# Ticker: PARA
# Earnings Growth: None
# Return on Equity: -0.29097998
# R&D Spending: None
#
# Ticker: FOX
# Earnings Growth: -0.08
# Return on Equity: 0.14313
# R&D Spending: None
#
# Ticker: NWS
# Earnings Growth: None
# Return on Equity: 0.03943
# R&D Spending: None
#
# Ticker: XOM
# Earnings Growth: 0.104
# Return on Equity: 0.1469
# R&D Spending: None
#
# Ticker: CVX
# Earnings Growth: -0.241
# Return on Equity: 0.11761
# R&D Spending: None
#
# Ticker: COP
# Earnings Growth: 0.076
# Return on Equity: 0.21968001
# R&D Spending: None
#
# Ticker: EOG
# Earnings Growth: 0.109
# Return on Equity: 0.27056998
# R&D Spending: None
#
# Ticker: SLB
# Earnings Growth: 0.069
# Return on Equity: 0.21972999
# R&D Spending: None
#
# Ticker: WMB
# Earnings Growth: -0.129
# Return on Equity: 0.20376
# R&D Spending: None
#
# Ticker: PSX
# Earnings Growth: -0.359
# Return on Equity: 0.16921
# R&D Spending: None
#
# Ticker: OKE
# Earnings Growth: 0.279
# Return on Equity: 0.21406999
# R&D Spending: None
#
# Ticker: MPC
# Earnings Growth: -0.186
# Return on Equity: 0.28934
# R&D Spending: None
#
# Ticker: KMI
# Earnings Growth: -0.009
# Return on Equity: 0.08012
# R&D Spending: None
#
# Ticker: VLO
# Earnings Growth: -0.499
# Return on Equity: 0.21823
# R&D Spending: None
#
# Ticker: HES
# Earnings Growth: 5.326
# Return on Equity: 0.30075002
# R&D Spending: None
#
# Ticker: BKR
# Earnings Growth: 0.45
# Return on Equity: 0.13033
# R&D Spending: None
#
# Ticker: OXY
# Earnings Growth: 0.635
# Return on Equity: 0.14427
# R&D Spending: None
#
# Ticker: FANG
# Earnings Growth: 0.528
# Return on Equity: 0.21341999
# R&D Spending: None
#
# Ticker: TRGP
# Earnings Growth: -0.076
# Return on Equity: 0.29883
# R&D Spending: None
#
# Ticker: HAL
# Earnings Growth: 0.182
# Return on Equity: 0.28903
# R&D Spending: None
#
# Ticker: DVN
# Earnings Growth: 0.252
# Return on Equity: 0.29691
# R&D Spending: None
#
# Ticker: EQT
# Earnings Growth: None
# Return on Equity: 0.051119998
# R&D Spending: None
#
# Ticker: CTRA
# Earnings Growth: 0.074
# Return on Equity: 0.102010004
# R&D Spending: None
#
# Ticker: MRO
# Earnings Growth: 0.319
# Return on Equity: 0.13327
# R&D Spending: None
#
# Ticker: APA
# Earnings Growth: 0.186
# Return on Equity: 0.7938
# R&D Spending: None
#
# Ticker: AMZN
# Earnings Growth: 0.938
# Return on Equity: 0.21933001
# R&D Spending: None
#
# Ticker: TSLA
# Earnings Growth: -0.462
# Return on Equity: 0.20861
# R&D Spending: None
#
# Ticker: COST
# Earnings Growth: 0.088
# Return on Equity: 0.30267
# R&D Spending: None
#
# Ticker: PEP
# Earnings Growth: 0.121
# Return on Equity: 0.51261
# R&D Spending: None
#
# Ticker: LIN
# Earnings Growth: 0.078
# Return on Equity: 0.16193001
# R&D Spending: None
#
# Ticker: AMGN
# Earnings Growth: -0.463
# Return on Equity: 0.49268
# R&D Spending: None
#
# Ticker: ISRG
# Earnings Growth: 0.237
# Return on Equity: 0.15767999
# R&D Spending: None
#
# Ticker: BKNG
# Earnings Growth: 0.272
# Return on Equity: None
# R&D Spending: None
#
# Ticker: HON
# Earnings Growth: 0.063
# Return on Equity: 0.32740003
# R&D Spending: None
#
# Ticker: VRTX
# Earnings Growth: None
# Return on Equity: -0.0324
# R&D Spending: None
#
# Ticker: ADP
# Earnings Growth: 0.072
# Return on Equity: 0.9314
# R&D Spending: None
#
# Ticker: SBUX
# Earnings Growth: -0.061
# Return on Equity: None
# R&D Spending: None
#
# Ticker: REGN
# Earnings Growth: 0.46
# Return on Equity: 0.16551
# R&D Spending: None
#
# Ticker: GILD
# Earnings Growth: 0.554
# Return on Equity: 0.05263
# R&D Spending: None
#
# Ticker: PDD
# Earnings Growth: 1.4
# Return on Equity: 0.49495998
# R&D Spending: None
#
# Ticker: MELI
# Earnings Growth: 1.029
# Return on Equity: 0.4736
# R&D Spending: None
#
# Ticker: MDLZ
# Earnings Growth: -0.351
# Return on Equity: 0.14033
# R&D Spending: None
#
# Ticker: CEG
# Earnings Growth: 0.008
# Return on Equity: 0.20031999
# R&D Spending: None
#
# Ticker: CTAS
# Earnings Growth: 0.183
# Return on Equity: 0.40462002
# R&D Spending: None
#
# Ticker: PYPL
# Earnings Growth: 0.174
# Return on Equity: 0.22034
# R&D Spending: None
#
# Ticker: ASML
# Earnings Growth: -0.187
# Return on Equity: 0.48567
# R&D Spending: None
#
# Ticker: MAR
# Earnings Growth: 0.13
# Return on Equity: None
# R&D Spending: None
#
# Ticker: ORLY
# Earnings Growth: 0.032
# Return on Equity: None
# R&D Spending: None
#
# Ticker: CSX
# Earnings Growth: 0.006
# Return on Equity: 0.28923
# R&D Spending: None
#
# Ticker: MRVL
# Earnings Growth: None
# Return on Equity: -0.06528
# R&D Spending: None
#
# Ticker: ABNB
# Earnings Growth: -0.125
# Return on Equity: 0.74175
# R&D Spending: None
#
# Ticker: DASH
# Earnings Growth: None
# Return on Equity: -0.06098
# R&D Spending: None
#
# Ticker: PCAR
# Earnings Growth: -0.086
# Return on Equity: 0.30283
# R&D Spending: None
#
# Ticker: AEP
# Earnings Growth: -0.366
# Return on Equity: 0.10514
# R&D Spending: None
#
# Ticker: CPRT
# Earnings Growth: -0.083
# Return on Equity: 0.20129
# R&D Spending: None
#
# Ticker: WDAY
# Earnings Growth: 0.661
# Return on Equity: 0.21080999
# R&D Spending: None
#
# Ticker: TTD
# Earnings Growth: 1.521
# Return on Equity: 0.11319
# R&D Spending: None
#
# Ticker: PAYX
# Earnings Growth: 0.017
# Return on Equity: 0.45672
# R&D Spending: None
#
# Ticker: KDP
# Earnings Growth: 0.058
# Return on Equity: 0.08723
# R&D Spending: None
#
# Ticker: MNST
# Earnings Growth: 0.051
# Return on Equity: 0.24615
# R&D Spending: None
#
# Ticker: ROST
# Earnings Growth: 0.205
# Return on Equity: 0.43236
# R&D Spending: None
#
# Ticker: AZN
# Earnings Growth: 0.06
# Return on Equity: 0.16736999
# R&D Spending: None
#
# Ticker: KHC
# Earnings Growth: -0.901
# Return on Equity: 0.03867
# R&D Spending: None
#
# Ticker: GEHC
# Earnings Growth: 0.022
# Return on Equity: 0.21218
# R&D Spending: None
#
# Ticker: MCHP
# Earnings Growth: -0.802
# Return on Equity: 0.20696
# R&D Spending: None
#
# Ticker: ODFL
# Earnings Growth: 0.113
# Return on Equity: 0.32136002
# R&D Spending: None
#
# Ticker: FAST
# Earnings Growth: -0.019
# Return on Equity: 0.33515
# R&D Spending: None
#
# Ticker: EXC
# Earnings Growth: 0.316
# Return on Equity: 0.09455
# R&D Spending: None
#
# Ticker: IDXX
# Earnings Growth: -0.086
# Return on Equity: 0.63246
# R&D Spending: None
#
# Ticker: DDOG
# Earnings Growth: None
# Return on Equity: 0.0804
# R&D Spending: None
#
# Ticker: VRSK
# Earnings Growth: 0.583
# Return on Equity: 2.42046
# R&D Spending: None
#
# Ticker: EA
# Earnings Growth: -0.293
# Return on Equity: 0.15624
# R&D Spending: None
#
# Ticker: BKR
# Earnings Growth: 0.45
# Return on Equity: 0.13033
# R&D Spending: None
#
# Ticker: CTSH
# Earnings Growth: 0.251
# Return on Equity: 0.16379999
# R&D Spending: None
#
# Ticker: FANG
# Earnings Growth: 0.528
# Return on Equity: 0.21341999
# R&D Spending: None
#
# Ticker: CCEP
# Earnings Growth: -0.07
# Return on Equity: 0.19393
# R&D Spending: None
#
# Ticker: XEL
# Earnings Growth: 0.038
# Return on Equity: 0.106400006
# R&D Spending: None
#
# Ticker: LULU
# Earnings Growth: 0.175
# Return on Equity: 0.43159
# R&D Spending: None
#
# Ticker: ON
# Earnings Growth: -0.393
# Return on Equity: 0.25236
# R&D Spending: None
#
# Ticker: CSGP
# Earnings Growth: -0.809
# Return on Equity: 0.02937
# R&D Spending: None
#
# Ticker: CDW
# Earnings Growth: 0.078
# Return on Equity: 0.58541
# R&D Spending: None
#
# Ticker: SMCI
# Earnings Growth: 0.61
# Return on Equity: 0.32469
# R&D Spending: None
#
# Ticker: DXCM
# Earnings Growth: 0.266
# Return on Equity: 0.29413
# R&D Spending: None
#
# Ticker: ANSS
# Earnings Growth: 0.85
# Return on Equity: 0.094289996
# R&D Spending: None
#
# Ticker: TEAM
# Earnings Growth: None
# Return on Equity: -0.35617
# R&D Spending: None
#
# Ticker: BIIB
# Earnings Growth: -0.017
# Return on Equity: 0.07628
# R&D Spending: None
#
# Ticker: TTWO
# Earnings Growth: None
# Return on Equity: -0.50901
# R&D Spending: None
#
# Ticker: ZS
# Earnings Growth: None
# Return on Equity: -0.057729997
# R&D Spending: None
#
# Ticker: MRNA
# Earnings Growth: None
# Return on Equity: -0.40941003
# R&D Spending: None
#
# Ticker: ILMN
# Earnings Growth: None
# Return on Equity: -0.76185995
# R&D Spending: None
#
# Ticker: GFS
# Earnings Growth: -0.349
# Return on Equity: 0.07461
# R&D Spending: None
#
# Ticker: MDB
# Earnings Growth: None
# Return on Equity: -0.19561
# R&D Spending: None
#
# Ticker: WBD
# Earnings Growth: None
# Return on Equity: -0.28667
# R&D Spending: None
#
# Ticker: ARM
# Earnings Growth: 1.1
# Return on Equity: 0.0858
# R&D Spending: None
#
# Ticker: DLTR
# Earnings Growth: -0.323
# Return on Equity: -0.12983
# R&D Spending: None
#
# ARK Invest selected stocks: ['AAPL', 'NVDA', 'MSFT', 'AVGO', 'ORCL', 'ACN', 'ADBE', 'IBM', 'QCOM', 'AMAT', 'PANW', 'LRCX', 'KLAC', 'ANET', 'PLTR', 'SNPS', 'APH', 'MSI', 'ADSK', 'FTNT', 'TEL', 'IT', 'CTSH', 'CDW', 'KEYS', 'NTAP', 'FSLR', 'SMCI', 'PTC', 'TER', 'TRMB', 'FFIV', 'META', 'GOOGL', 'GOOG', 'NFLX', 'TMUS', 'CHTR', 'XOM', 'COP', 'EOG', 'SLB', 'OKE', 'HES', 'BKR', 'OXY', 'FANG', 'HAL', 'DVN', 'CTRA', 'MRO', 'APA', 'AMZN', 'COST', 'PEP', 'LIN', 'ISRG', 'HON', 'ADP', 'REGN', 'PDD', 'MELI', 'CTAS', 'PYPL', 'WDAY', 'TTD', 'MNST', 'ROST', 'AZN', 'ODFL', 'VRSK', 'BKR', 'CTSH', 'FANG', 'LULU', 'CDW', 'SMCI', 'DXCM']

# %%
sample_tickers = tickers[:5]  # Take the first 5 tickers for testing

for ticker in sample_tickers:
    stock = yf.Ticker(ticker)
    stock_info = stock.info
    print(f"Ticker: {ticker}")
    print(f"Available keys in stock.info: {list(stock_info.keys())}\n")
# Out:
# Ticker: AAPL
# Available keys in stock.info: ['address1', 'city', 'state', 'zip', 'country', 'phone', 'website', 'industry', 'industryKey', 'industryDisp', 'sector', 'sectorKey', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'irWebsite', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate', 'dividendYield', 'exDividendDate', 'payoutRatio', 'fiveYearAvgDividendYield', 'beta', 'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth', 'sharesShortPreviousMonthDate', 'dateShortInterest', 'sharesPercentSharesOut', 'heldPercentInsiders', 'heldPercentInstitutions', 'shortRatio', 'shortPercentOfFloat', 'impliedSharesOutstanding', 'bookValue', 'priceToBook', 'lastFiscalYearEnd', 'nextFiscalYearEnd', 'mostRecentQuarter', 'earningsQuarterlyGrowth', 'netIncomeToCommon', 'trailingEps', 'forwardEps', 'pegRatio', 'lastSplitFactor', 'lastSplitDate', 'enterpriseToRevenue', 'enterpriseToEbitda', '52WeekChange', 'SandP52WeekChange', 'lastDividendValue', 'lastDividendDate', 'exchange', 'quoteType', 'symbol', 'underlyingSymbol', 'shortName', 'longName', 'firstTradeDateEpochUtc', 'timeZoneFullName', 'timeZoneShortName', 'uuid', 'messageBoardId', 'gmtOffSetMilliseconds', 'currentPrice', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'recommendationKey', 'numberOfAnalystOpinions', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'financialCurrency', 'trailingPegRatio']
#
# Ticker: NVDA
# Available keys in stock.info: ['address1', 'city', 'state', 'zip', 'country', 'phone', 'website', 'industry', 'industryKey', 'industryDisp', 'sector', 'sectorKey', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'irWebsite', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate', 'dividendYield', 'exDividendDate', 'payoutRatio', 'fiveYearAvgDividendYield', 'beta', 'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth', 'sharesShortPreviousMonthDate', 'dateShortInterest', 'sharesPercentSharesOut', 'heldPercentInsiders', 'heldPercentInstitutions', 'shortRatio', 'shortPercentOfFloat', 'impliedSharesOutstanding', 'bookValue', 'priceToBook', 'lastFiscalYearEnd', 'nextFiscalYearEnd', 'mostRecentQuarter', 'earningsQuarterlyGrowth', 'netIncomeToCommon', 'trailingEps', 'forwardEps', 'pegRatio', 'lastSplitFactor', 'lastSplitDate', 'enterpriseToRevenue', 'enterpriseToEbitda', '52WeekChange', 'SandP52WeekChange', 'lastDividendValue', 'lastDividendDate', 'exchange', 'quoteType', 'symbol', 'underlyingSymbol', 'shortName', 'longName', 'firstTradeDateEpochUtc', 'timeZoneFullName', 'timeZoneShortName', 'uuid', 'messageBoardId', 'gmtOffSetMilliseconds', 'currentPrice', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'recommendationKey', 'numberOfAnalystOpinions', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'financialCurrency', 'trailingPegRatio']
#
# Ticker: MSFT
# Available keys in stock.info: ['address1', 'city', 'state', 'zip', 'country', 'phone', 'website', 'industry', 'industryKey', 'industryDisp', 'sector', 'sectorKey', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'irWebsite', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate', 'dividendYield', 'exDividendDate', 'payoutRatio', 'fiveYearAvgDividendYield', 'beta', 'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth', 'sharesShortPreviousMonthDate', 'dateShortInterest', 'sharesPercentSharesOut', 'heldPercentInsiders', 'heldPercentInstitutions', 'shortRatio', 'shortPercentOfFloat', 'impliedSharesOutstanding', 'bookValue', 'priceToBook', 'lastFiscalYearEnd', 'nextFiscalYearEnd', 'mostRecentQuarter', 'earningsQuarterlyGrowth', 'netIncomeToCommon', 'trailingEps', 'forwardEps', 'pegRatio', 'lastSplitFactor', 'lastSplitDate', 'enterpriseToRevenue', 'enterpriseToEbitda', '52WeekChange', 'SandP52WeekChange', 'lastDividendValue', 'lastDividendDate', 'exchange', 'quoteType', 'symbol', 'underlyingSymbol', 'shortName', 'longName', 'firstTradeDateEpochUtc', 'timeZoneFullName', 'timeZoneShortName', 'uuid', 'messageBoardId', 'gmtOffSetMilliseconds', 'currentPrice', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'recommendationKey', 'numberOfAnalystOpinions', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'financialCurrency', 'trailingPegRatio']
#
# Ticker: AVGO
# Available keys in stock.info: ['address1', 'city', 'state', 'zip', 'country', 'phone', 'website', 'industry', 'industryKey', 'industryDisp', 'sector', 'sectorKey', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate', 'dividendYield', 'exDividendDate', 'payoutRatio', 'fiveYearAvgDividendYield', 'beta', 'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth', 'sharesShortPreviousMonthDate', 'dateShortInterest', 'sharesPercentSharesOut', 'heldPercentInsiders', 'heldPercentInstitutions', 'shortRatio', 'shortPercentOfFloat', 'impliedSharesOutstanding', 'bookValue', 'priceToBook', 'lastFiscalYearEnd', 'nextFiscalYearEnd', 'mostRecentQuarter', 'earningsQuarterlyGrowth', 'netIncomeToCommon', 'trailingEps', 'forwardEps', 'pegRatio', 'lastSplitFactor', 'lastSplitDate', 'enterpriseToRevenue', 'enterpriseToEbitda', '52WeekChange', 'SandP52WeekChange', 'lastDividendValue', 'lastDividendDate', 'exchange', 'quoteType', 'symbol', 'underlyingSymbol', 'shortName', 'longName', 'firstTradeDateEpochUtc', 'timeZoneFullName', 'timeZoneShortName', 'uuid', 'messageBoardId', 'gmtOffSetMilliseconds', 'currentPrice', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'recommendationKey', 'numberOfAnalystOpinions', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'financialCurrency', 'trailingPegRatio']
#
# Ticker: CRM
# Available keys in stock.info: ['address1', 'address2', 'city', 'state', 'zip', 'country', 'phone', 'fax', 'website', 'industry', 'industryKey', 'industryDisp', 'industrySymbol', 'sector', 'sectorKey', 'sectorDisp', 'longBusinessSummary', 'fullTimeEmployees', 'companyOfficers', 'auditRisk', 'boardRisk', 'compensationRisk', 'shareHolderRightsRisk', 'overallRisk', 'governanceEpochDate', 'compensationAsOfEpochDate', 'irWebsite', 'maxAge', 'priceHint', 'previousClose', 'open', 'dayLow', 'dayHigh', 'regularMarketPreviousClose', 'regularMarketOpen', 'regularMarketDayLow', 'regularMarketDayHigh', 'dividendRate', 'dividendYield', 'exDividendDate', 'payoutRatio', 'beta', 'trailingPE', 'forwardPE', 'volume', 'regularMarketVolume', 'averageVolume', 'averageVolume10days', 'averageDailyVolume10Day', 'bid', 'ask', 'bidSize', 'askSize', 'marketCap', 'fiftyTwoWeekLow', 'fiftyTwoWeekHigh', 'priceToSalesTrailing12Months', 'fiftyDayAverage', 'twoHundredDayAverage', 'trailingAnnualDividendRate', 'trailingAnnualDividendYield', 'currency', 'enterpriseValue', 'profitMargins', 'floatShares', 'sharesOutstanding', 'sharesShort', 'sharesShortPriorMonth', 'sharesShortPreviousMonthDate', 'dateShortInterest', 'sharesPercentSharesOut', 'heldPercentInsiders', 'heldPercentInstitutions', 'shortRatio', 'shortPercentOfFloat', 'impliedSharesOutstanding', 'bookValue', 'priceToBook', 'lastFiscalYearEnd', 'nextFiscalYearEnd', 'mostRecentQuarter', 'earningsQuarterlyGrowth', 'netIncomeToCommon', 'trailingEps', 'forwardEps', 'pegRatio', 'lastSplitFactor', 'lastSplitDate', 'enterpriseToRevenue', 'enterpriseToEbitda', '52WeekChange', 'SandP52WeekChange', 'lastDividendValue', 'lastDividendDate', 'exchange', 'quoteType', 'symbol', 'underlyingSymbol', 'shortName', 'longName', 'firstTradeDateEpochUtc', 'timeZoneFullName', 'timeZoneShortName', 'uuid', 'messageBoardId', 'gmtOffSetMilliseconds', 'currentPrice', 'targetHighPrice', 'targetLowPrice', 'targetMeanPrice', 'targetMedianPrice', 'recommendationMean', 'recommendationKey', 'numberOfAnalystOpinions', 'totalCash', 'totalCashPerShare', 'ebitda', 'totalDebt', 'quickRatio', 'currentRatio', 'totalRevenue', 'debtToEquity', 'revenuePerShare', 'returnOnAssets', 'returnOnEquity', 'freeCashflow', 'operatingCashflow', 'earningsGrowth', 'revenueGrowth', 'grossMargins', 'ebitdaMargins', 'operatingMargins', 'financialCurrency', 'trailingPegRatio']

# %%
def marty_schwartz_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock_data = data['Close'][ticker]
        ma_50 = stock_data.rolling(window=50).mean()
        ma_200 = stock_data.rolling(window=200).mean()
        
        if stock_data[-1] > ma_50[-1] and stock_data[-1] > ma_200[-1]:  # Stock above both 50-day and 200-day MA
            selected_stocks.append(ticker)
    
    return selected_stocks

marty_schwartz_stocks = marty_schwartz_selection(data)
print("Marty Schwartz selected stocks:", marty_schwartz_stocks)
# Out:
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/2601337522.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if stock_data[-1] > ma_50[-1] and stock_data[-1] > ma_200[-1]:  # Stock above both 50-day and 200-day MA
# Marty Schwartz selected stocks: ['AAPL', 'NVDA', 'AVGO', 'CRM', 'AMD', 'ORCL', 'ACN', 'CSCO', 'IBM', 'NOW', 'TXN', 'AMAT', 'PANW', 'ADI', 'KLAC', 'ANET', 'PLTR', 'APH', 'MSI', 'ADSK', 'FTNT', 'FICO', 'MPWR', 'IT', 'CTSH', 'HPQ', 'DELL', 'GLW', 'HPE', 'KEYS', 'NTAP', 'TYL', 'STX', 'GDDY', 'WDC', 'TER', 'TDY', 'ZBRA', 'TRMB', 'GEN', 'JBL', 'FFIV', 'JNPR', 'META', 'GOOGL', 'GOOG', 'NFLX', 'TMUS', 'CMCSA', 'T', 'VZ', 'OMC', 'LYV', 'MTCH', 'FOXA', 'FOX', 'XOM', 'EOG', 'WMB', 'OKE', 'KMI', 'BKR', 'FANG', 'TRGP', 'EQT', 'MRO', 'AMZN', 'TSLA', 'COST', 'LIN', 'ISRG', 'BKNG', 'HON', 'ADP', 'SBUX', 'GILD', 'PDD', 'MELI', 'CEG', 'CTAS', 'PYPL', 'MAR', 'ORLY', 'MRVL', 'DASH', 'CPRT', 'TTD', 'PAYX', 'FAST', 'EXC', 'DDOG', 'VRSK', 'BKR', 'CTSH', 'FANG', 'XEL', 'ILMN']

# %%
def william_oneil_selection(data):
    selected_stocks = []
    # Extract tickers from the data columns
    tickers = data.columns.levels[1]
    
    for ticker in tickers:
        stock = yf.Ticker(ticker)
        info = stock.info
        earnings_growth = info.get("earningsGrowth", None)
        beta = info.get("beta", None)
        shares_outstanding = info.get("sharesOutstanding", None)
        
        print(f"{ticker} stats:")
        print(f"  Earnings Growth: {earnings_growth}")
        print(f"  Beta: {beta}")
        print(f"  Shares Outstanding: {shares_outstanding}")
        print("-" * 40)
        
        # Check if all required data is available
        if earnings_growth is None or beta is None or shares_outstanding is None:
            continue  # Skip this stock due to missing data
        
        # Apply selection criteria
        if (earnings_growth >= 0.2 and
            beta > 1.5 and
            shares_outstanding <= 25529999872):
            selected_stocks.append(ticker)
            
    return selected_stocks

# Call the function with your data
william_oneil_stocks = william_oneil_selection(data)
print("William O'Neil selected stocks:", william_oneil_stocks)
# Out:
# AAPL stats:
#   Earnings Growth: 0.111
#   Beta: 1.239
#   Shares Outstanding: 15204100096
# ----------------------------------------
# ABNB stats:
#   Earnings Growth: -0.125
#   Beta: 1.172
#   Shares Outstanding: 440001984
# ----------------------------------------
# ACN stats:
#   Earnings Growth: 0.237
#   Beta: 1.239
#   Shares Outstanding: 626000000
# ----------------------------------------
# ADBE stats:
#   Earnings Growth: 0.233
#   Beta: 1.289
#   Shares Outstanding: 440200000
# ----------------------------------------
# ADI stats:
#   Earnings Growth: -0.546
#   Beta: 1.071
#   Shares Outstanding: 496492992
# ----------------------------------------
# ADP stats:
#   Earnings Growth: 0.072
#   Beta: 0.801
#   Shares Outstanding: 407825984
# ----------------------------------------
# ADSK stats:
#   Earnings Growth: 0.262
#   Beta: 1.478
#   Shares Outstanding: 215508992
# ----------------------------------------
# AEP stats:
#   Earnings Growth: -0.366
#   Beta: 0.534
#   Shares Outstanding: 532120000
# ----------------------------------------
# AKAM stats:
#   Earnings Growth: 0.024
#   Beta: 0.676
#   Shares Outstanding: 151526000
# ----------------------------------------
# AMAT stats:
#   Earnings Growth: 0.108
#   Beta: 1.54
#   Shares Outstanding: 824403968
# ----------------------------------------
# AMD stats:
#   Earnings Growth: 8.553
#   Beta: 1.695
#   Shares Outstanding: 1618480000
# ----------------------------------------
# AMGN stats:
#   Earnings Growth: -0.463
#   Beta: 0.602
#   Shares Outstanding: 537329024
# ----------------------------------------
# AMZN stats:
#   Earnings Growth: 0.938
#   Beta: 1.147
#   Shares Outstanding: 10495599616
# ----------------------------------------
# ANET stats:
#   Earnings Growth: 0.342
#   Beta: 1.075
#   Shares Outstanding: 314152992
# ----------------------------------------
# ANSS stats:
#   Earnings Growth: 0.85
#   Beta: 1.113
#   Shares Outstanding: 87386600
# ----------------------------------------
# APA stats:
#   Earnings Growth: 0.186
#   Beta: 3.232
#   Shares Outstanding: 369904992
# ----------------------------------------
# APH stats:
#   Earnings Growth: 0.108
#   Beta: 1.243
#   Shares Outstanding: 1204290048
# ----------------------------------------
# ARM stats:
#   Earnings Growth: 1.1
#   Beta: None
#   Shares Outstanding: 1048000000
# ----------------------------------------
# ASML stats:
#   Earnings Growth: -0.187
#   Beta: 1.052
#   Shares Outstanding: 393200000
# ----------------------------------------
# AVGO stats:
#   Earnings Growth: 1.881
#   Beta: 1.184
#   Shares Outstanding: 4670580224
# ----------------------------------------
# AZN stats:
#   Earnings Growth: 0.06
#   Beta: 0.166
#   Shares Outstanding: 3100590080
# ----------------------------------------
# BIIB stats:
#   Earnings Growth: -0.017
#   Beta: -0.06
#   Shares Outstanding: 145662000
# ----------------------------------------
# BKNG stats:
#   Earnings Growth: 0.272
#   Beta: 1.402
#   Shares Outstanding: 33524400
# ----------------------------------------
# BKR stats:
#   Earnings Growth: 0.45
#   Beta: 1.366
#   Shares Outstanding: 993424000
# ----------------------------------------
# CCEP stats:
#   Earnings Growth: -0.07
#   Beta: 0.755
#   Shares Outstanding: 460934016
# ----------------------------------------
# CDNS stats:
#   Earnings Growth: 0.037
#   Beta: 1.019
#   Shares Outstanding: 273820000
# ----------------------------------------
# CDW stats:
#   Earnings Growth: 0.078
#   Beta: 1.032
#   Shares Outstanding: 133576000
# ----------------------------------------
# CEG stats:
#   Earnings Growth: 0.008
#   Beta: 0.768
#   Shares Outstanding: 312688992
# ----------------------------------------
# CHTR stats:
#   Earnings Growth: 0.055
#   Beta: 1.047
#   Shares Outstanding: 142740992
# ----------------------------------------
# CMCSA stats:
#   Earnings Growth: -0.02
#   Beta: 1.012
#   Shares Outstanding: 3863059968
# ----------------------------------------
# COP stats:
#   Earnings Growth: 0.076
#   Beta: 1.223
#   Shares Outstanding: 1161250048
# ----------------------------------------
# COST stats:
#   Earnings Growth: 0.088
#   Beta: 0.787
#   Shares Outstanding: 443126016
# ----------------------------------------
# CPRT stats:
#   Earnings Growth: -0.083
#   Beta: 1.269
#   Shares Outstanding: 963286976
# ----------------------------------------
# CRM stats:
#   Earnings Growth: 0.148
#   Beta: 1.3
#   Shares Outstanding: 956000000
# ----------------------------------------
# CRWD stats:
#   Earnings Growth: 5.333
#   Beta: 1.098
#   Shares Outstanding: 232716992
# ----------------------------------------
# CSCO stats:
#   Earnings Growth: -0.439
#   Beta: 0.822
#   Shares Outstanding: 3990729984
# ----------------------------------------
# CSGP stats:
#   Earnings Growth: -0.809
#   Beta: 0.814
#   Shares Outstanding: 409816992
# ----------------------------------------
# CSX stats:
#   Earnings Growth: 0.006
#   Beta: 1.189
#   Shares Outstanding: 1938739968
# ----------------------------------------
# CTAS stats:
#   Earnings Growth: 0.183
#   Beta: 1.311
#   Shares Outstanding: 403299008
# ----------------------------------------
# CTRA stats:
#   Earnings Growth: 0.074
#   Beta: 0.198
#   Shares Outstanding: 739273984
# ----------------------------------------
# CTSH stats:
#   Earnings Growth: 0.251
#   Beta: 1.049
#   Shares Outstanding: 497128992
# ----------------------------------------
# CVX stats:
#   Earnings Growth: -0.241
#   Beta: 1.079
#   Shares Outstanding: 1814749952
# ----------------------------------------
# DASH stats:
#   Earnings Growth: None
#   Beta: 1.696
#   Shares Outstanding: 384625984
# ----------------------------------------
# DDOG stats:
#   Earnings Growth: None
#   Beta: 1.103
#   Shares Outstanding: 311110016
# ----------------------------------------
# DELL stats:
#   Earnings Growth: 0.857
#   Beta: 0.959
#   Shares Outstanding: 333873984
# ----------------------------------------
# DIS stats:
#   Earnings Growth: None
#   Beta: 1.401
#   Shares Outstanding: 1813590016
# ----------------------------------------
# DLTR stats:
#   Earnings Growth: -0.323
#   Beta: 0.864
#   Shares Outstanding: 214992000
# ----------------------------------------
# DVN stats:
#   Earnings Growth: 0.252
#   Beta: 2.061
#   Shares Outstanding: 658259008
# ----------------------------------------
# DXCM stats:
#   Earnings Growth: 0.266
#   Beta: 1.18
#   Shares Outstanding: 400727008
# ----------------------------------------
# EA stats:
#   Earnings Growth: -0.293
#   Beta: 0.788
#   Shares Outstanding: 264200000
# ----------------------------------------
# ENPH stats:
#   Earnings Growth: -0.927
#   Beta: 1.719
#   Shares Outstanding: 135422000
# ----------------------------------------
# EOG stats:
#   Earnings Growth: 0.109
#   Beta: 1.285
#   Shares Outstanding: 568600000
# ----------------------------------------
# EPAM stats:
#   Earnings Growth: -0.163
#   Beta: 1.449
#   Shares Outstanding: 56935400
# ----------------------------------------
# EQT stats:
#   Earnings Growth: None
#   Beta: 1.064
#   Shares Outstanding: 594028992
# ----------------------------------------
# EXC stats:
#   Earnings Growth: 0.316
#   Beta: 0.604
#   Shares Outstanding: 1000499968
# ----------------------------------------
# FANG stats:
#   Earnings Growth: 0.528
#   Beta: 1.876
#   Shares Outstanding: 292742016
# ----------------------------------------
# FAST stats:
#   Earnings Growth: -0.019
#   Beta: 0.997
#   Shares Outstanding: 572646016
# ----------------------------------------
# FFIV stats:
#   Earnings Growth: 0.649
#   Beta: 1.06
#   Shares Outstanding: 58284400
# ----------------------------------------
# FICO stats:
#   Earnings Growth: -0.006
#   Beta: 1.352
#   Shares Outstanding: 24518500
# ----------------------------------------
# FOX stats:
#   Earnings Growth: -0.08
#   Beta: 0.771
#   Shares Outstanding: 235580992
# ----------------------------------------
# FOXA stats:
#   Earnings Growth: -0.08
#   Beta: 0.771
#   Shares Outstanding: 222598000
# ----------------------------------------
# FSLR stats:
#   Earnings Growth: 1.044
#   Beta: 1.442
#   Shares Outstanding: 107047000
# ----------------------------------------
# FTNT stats:
#   Earnings Growth: 0.485
#   Beta: 0.997
#   Shares Outstanding: 764908032
# ----------------------------------------
# GDDY stats:
#   Earnings Growth: 0.87
#   Beta: 1.121
#   Shares Outstanding: 140972992
# ----------------------------------------
# GEHC stats:
#   Earnings Growth: 0.022
#   Beta: None
#   Shares Outstanding: 456662016
# ----------------------------------------
# GEN stats:
#   Earnings Growth: None
#   Beta: 1.061
#   Shares Outstanding: 615524992
# ----------------------------------------
# GFS stats:
#   Earnings Growth: -0.349
#   Beta: 1.513
#   Shares Outstanding: 551777024
# ----------------------------------------
# GILD stats:
#   Earnings Growth: 0.554
#   Beta: 0.199
#   Shares Outstanding: 1244989952
# ----------------------------------------
# GLW stats:
#   Earnings Growth: -0.636
#   Beta: 1.039
#   Shares Outstanding: 855700992
# ----------------------------------------
# GOOG stats:
#   Earnings Growth: 0.314
#   Beta: 1.038
#   Shares Outstanding: 5584999936
# ----------------------------------------
# GOOGL stats:
#   Earnings Growth: 0.314
#   Beta: 1.038
#   Shares Outstanding: 5858999808
# ----------------------------------------
# HAL stats:
#   Earnings Growth: 0.182
#   Beta: 1.9
#   Shares Outstanding: 882828992
# ----------------------------------------
# HES stats:
#   Earnings Growth: 5.326
#   Beta: 1.162
#   Shares Outstanding: 308115008
# ----------------------------------------
# HON stats:
#   Earnings Growth: 0.063
#   Beta: 1.027
#   Shares Outstanding: 649670976
# ----------------------------------------
# HPE stats:
#   Earnings Growth: 0.086
#   Beta: 1.205
#   Shares Outstanding: 1298669952
# ----------------------------------------
# HPQ stats:
#   Earnings Growth: -0.145
#   Beta: 1.081
#   Shares Outstanding: 963408000
# ----------------------------------------
# IBM stats:
#   Earnings Growth: 0.141
#   Beta: 0.697
#   Shares Outstanding: 921148032
# ----------------------------------------
# IDXX stats:
#   Earnings Growth: -0.086
#   Beta: 1.333
#   Shares Outstanding: 82305904
# ----------------------------------------
# ILMN stats:
#   Earnings Growth: None
#   Beta: 1.147
#   Shares Outstanding: 159300000
# ----------------------------------------
# INTC stats:
#   Earnings Growth: None
#   Beta: 1.023
#   Shares Outstanding: 4276000000
# ----------------------------------------
# INTU stats:
#   Earnings Growth: -0.185
#   Beta: 1.241
#   Shares Outstanding: 280292000
# ----------------------------------------
# IPG stats:
#   Earnings Growth: -0.162
#   Beta: 1.082
#   Shares Outstanding: 375591008
# ----------------------------------------
# ISRG stats:
#   Earnings Growth: 0.237
#   Beta: 1.393
#   Shares Outstanding: 355353984
# ----------------------------------------
# IT stats:
#   Earnings Growth: 0.181
#   Beta: 1.323
#   Shares Outstanding: 77059504
# ----------------------------------------
# JBL stats:
#   Earnings Growth: 0.019
#   Beta: 1.249
#   Shares Outstanding: 113445000
# ----------------------------------------
# JNPR stats:
#   Earnings Growth: 0.429
#   Beta: 0.921
#   Shares Outstanding: 329163008
# ----------------------------------------
# KDP stats:
#   Earnings Growth: 0.058
#   Beta: 0.619
#   Shares Outstanding: 1356089984
# ----------------------------------------
# KEYS stats:
#   Earnings Growth: 0.379
#   Beta: 0.975
#   Shares Outstanding: 173543008
# ----------------------------------------
# KHC stats:
#   Earnings Growth: -0.901
#   Beta: 0.477
#   Shares Outstanding: 1209080064
# ----------------------------------------
# KLAC stats:
#   Earnings Growth: 0.245
#   Beta: 1.271
#   Shares Outstanding: 133976000
# ----------------------------------------
# KMI stats:
#   Earnings Growth: -0.009
#   Beta: 0.921
#   Shares Outstanding: 2219460096
# ----------------------------------------
# LIN stats:
#   Earnings Growth: 0.078
#   Beta: 0.944
#   Shares Outstanding: 477503008
# ----------------------------------------
# LRCX stats:
#   Earnings Growth: 0.303
#   Beta: 1.481
#   Shares Outstanding: 1296109952
# ----------------------------------------
# LULU stats:
#   Earnings Growth: 0.175
#   Beta: 1.254
#   Shares Outstanding: 117661000
# ----------------------------------------
# LYV stats:
#   Earnings Growth: 0.009
#   Beta: 1.347
#   Shares Outstanding: 232114000
# ----------------------------------------
# MAR stats:
#   Earnings Growth: 0.13
#   Beta: 1.592
#   Shares Outstanding: 281523008
# ----------------------------------------
# MCHP stats:
#   Earnings Growth: -0.802
#   Beta: 1.516
#   Shares Outstanding: 536504992
# ----------------------------------------
# MDB stats:
#   Earnings Growth: None
#   Beta: 1.153
#   Shares Outstanding: 73869504
# ----------------------------------------
# MDLZ stats:
#   Earnings Growth: -0.351
#   Beta: 0.549
#   Shares Outstanding: 1335800064
# ----------------------------------------
# MELI stats:
#   Earnings Growth: 1.029
#   Beta: 1.606
#   Shares Outstanding: 50697400
# ----------------------------------------
# META stats:
#   Earnings Growth: 0.732
#   Beta: 1.216
#   Shares Outstanding: 2184730112
# ----------------------------------------
# MNST stats:
#   Earnings Growth: 0.051
#   Beta: 0.741
#   Shares Outstanding: 979480000
# ----------------------------------------
# MPC stats:
#   Earnings Growth: -0.186
#   Beta: 1.358
#   Shares Outstanding: 334684000
# ----------------------------------------
# MPWR stats:
#   Earnings Growth: 0.005
#   Beta: 1.117
#   Shares Outstanding: 48752000
# ----------------------------------------
# MRNA stats:
#   Earnings Growth: None
#   Beta: 1.661
#   Shares Outstanding: 384396000
# ----------------------------------------
# MRO stats:
#   Earnings Growth: 0.319
#   Beta: 2.162
#   Shares Outstanding: 559382976
# ----------------------------------------
# MRVL stats:
#   Earnings Growth: None
#   Beta: 1.449
#   Shares Outstanding: 866200000
# ----------------------------------------
# MSFT stats:
#   Earnings Growth: 0.097
#   Beta: 0.896
#   Shares Outstanding: 7433039872
# ----------------------------------------
# MSI stats:
#   Earnings Growth: 0.209
#   Beta: 0.977
#   Shares Outstanding: 166840992
# ----------------------------------------
# MTCH stats:
#   Earnings Growth: 0.017
#   Beta: 1.487
#   Shares Outstanding: 257895008
# ----------------------------------------
# MU stats:
#   Earnings Growth: None
#   Beta: 1.179
#   Shares Outstanding: 1108739968
# ----------------------------------------
# NFLX stats:
#   Earnings Growth: 0.483
#   Beta: 1.261
#   Shares Outstanding: 429164992
# ----------------------------------------
# NOW stats:
#   Earnings Growth: -0.752
#   Beta: 0.988
#   Shares Outstanding: 205856992
# ----------------------------------------
# NTAP stats:
#   Earnings Growth: 0.696
#   Beta: 1.219
#   Shares Outstanding: 204783008
# ----------------------------------------
# NVDA stats:
#   Earnings Growth: 1.68
#   Beta: 1.669
#   Shares Outstanding: 24529999872
# ----------------------------------------
# NWS stats:
#   Earnings Growth: None
#   Beta: 1.354
#   Shares Outstanding: 189947008
# ----------------------------------------
# NWSA stats:
#   Earnings Growth: None
#   Beta: 1.354
#   Shares Outstanding: 377679008
# ----------------------------------------
# NXPI stats:
#   Earnings Growth: -0.049
#   Beta: 1.493
#   Shares Outstanding: 254732992
# ----------------------------------------
# ODFL stats:
#   Earnings Growth: 0.113
#   Beta: 0.992
#   Shares Outstanding: 214296992
# ----------------------------------------
# OKE stats:
#   Earnings Growth: 0.279
#   Beta: 1.631
#   Shares Outstanding: 584073984
# ----------------------------------------
# OMC stats:
#   Earnings Growth: -0.093
#   Beta: 0.964
#   Shares Outstanding: 195648992
# ----------------------------------------
# ON stats:
#   Earnings Growth: -0.393
#   Beta: 1.65
#   Shares Outstanding: 428356000
# ----------------------------------------
# ORCL stats:
#   Earnings Growth: 0.198
#   Beta: 1.008
#   Shares Outstanding: 2771059968
# ----------------------------------------
# ORLY stats:
#   Earnings Growth: 0.032
#   Beta: 0.924
#   Shares Outstanding: 58005700
# ----------------------------------------
# OXY stats:
#   Earnings Growth: 0.635
#   Beta: 1.598
#   Shares Outstanding: 916196992
# ----------------------------------------
# PANW stats:
#   Earnings Growth: 0.591
#   Beta: 1.127
#   Shares Outstanding: 325600000
# ----------------------------------------
# PARA stats:
#   Earnings Growth: None
#   Beta: 1.771
#   Shares Outstanding: 626012032
# ----------------------------------------
# PAYX stats:
#   Earnings Growth: 0.017
#   Beta: 0.993
#   Shares Outstanding: 359897984
# ----------------------------------------
# PCAR stats:
#   Earnings Growth: -0.086
#   Beta: 0.901
#   Shares Outstanding: 524222016
# ----------------------------------------
# PDD stats:
#   Earnings Growth: 1.4
#   Beta: 0.698
#   Shares Outstanding: 1388770048
# ----------------------------------------
# PEP stats:
#   Earnings Growth: 0.121
#   Beta: 0.539
#   Shares Outstanding: 1373570048
# ----------------------------------------
# PLTR stats:
#   Earnings Growth: 5.0
#   Beta: 2.72
#   Shares Outstanding: 2142320000
# ----------------------------------------
# PSX stats:
#   Earnings Growth: -0.359
#   Beta: 1.318
#   Shares Outstanding: 418568992
# ----------------------------------------
# PTC stats:
#   Earnings Growth: 0.118
#   Beta: 1.175
#   Shares Outstanding: 120135000
# ----------------------------------------
# PYPL stats:
#   Earnings Growth: 0.174
#   Beta: 1.441
#   Shares Outstanding: 1022329984
# ----------------------------------------
# QCOM stats:
#   Earnings Growth: 0.174
#   Beta: 1.282
#   Shares Outstanding: 1114000000
# ----------------------------------------
# QRVO stats:
#   Earnings Growth: None
#   Beta: 1.451
#   Shares Outstanding: 94861296
# ----------------------------------------
# REGN stats:
#   Earnings Growth: 0.46
#   Beta: 0.115
#   Shares Outstanding: 108417000
# ----------------------------------------
# ROP stats:
#   Earnings Growth: -0.081
#   Beta: 1.021
#   Shares Outstanding: 107199000
# ----------------------------------------
# ROST stats:
#   Earnings Growth: 0.205
#   Beta: 1.091
#   Shares Outstanding: 331761984
# ----------------------------------------
# SBUX stats:
#   Earnings Growth: -0.061
#   Beta: 0.961
#   Shares Outstanding: 1133200000
# ----------------------------------------
# SLB stats:
#   Earnings Growth: 0.069
#   Beta: 1.525
#   Shares Outstanding: 1419840000
# ----------------------------------------
# SMCI stats:
#   Earnings Growth: 0.61
#   Beta: 1.231
#   Shares Outstanding: 585564992
# ----------------------------------------
# SNPS stats:
#   Earnings Growth: 0.204
#   Beta: 1.075
#   Shares Outstanding: 153614000
# ----------------------------------------
# STX stats:
#   Earnings Growth: None
#   Beta: 1.062
#   Shares Outstanding: 210490000
# ----------------------------------------
# SWKS stats:
#   Earnings Growth: -0.385
#   Beta: 1.199
#   Shares Outstanding: 159716000
# ----------------------------------------
# T stats:
#   Earnings Growth: -0.197
#   Beta: 0.737
#   Shares Outstanding: 7170240000
# ----------------------------------------
# TDY stats:
#   Earnings Growth: -0.026
#   Beta: 1.015
#   Shares Outstanding: 46784200
# ----------------------------------------
# TEAM stats:
#   Earnings Growth: None
#   Beta: 0.734
#   Shares Outstanding: 160032992
# ----------------------------------------
# TEL stats:
#   Earnings Growth: 0.114
#   Beta: 1.323
#   Shares Outstanding: 303919008
# ----------------------------------------
# TER stats:
#   Earnings Growth: 0.562
#   Beta: 1.49
#   Shares Outstanding: 163176000
# ----------------------------------------
# TMUS stats:
#   Earnings Growth: 0.339
#   Beta: 0.508
#   Shares Outstanding: 1166780032
# ----------------------------------------
# TRGP stats:
#   Earnings Growth: -0.076
#   Beta: 2.249
#   Shares Outstanding: 219080000
# ----------------------------------------
# TRMB stats:
#   Earnings Growth: 28.705
#   Beta: 1.487
#   Shares Outstanding: 244208000
# ----------------------------------------
# TSLA stats:
#   Earnings Growth: -0.462
#   Beta: 2.297
#   Shares Outstanding: 3194639872
# ----------------------------------------
# TTD stats:
#   Earnings Growth: 1.521
#   Beta: 1.482
#   Shares Outstanding: 449332992
# ----------------------------------------
# TTWO stats:
#   Earnings Growth: None
#   Beta: 0.856
#   Shares Outstanding: 175283008
# ----------------------------------------
# TXN stats:
#   Earnings Growth: -0.348
#   Beta: 0.973
#   Shares Outstanding: 913046016
# ----------------------------------------
# TYL stats:
#   Earnings Growth: 0.365
#   Beta: 0.776
#   Shares Outstanding: 42672700
# ----------------------------------------
# VLO stats:
#   Earnings Growth: -0.499
#   Beta: 1.376
#   Shares Outstanding: 320380000
# ----------------------------------------
# VRSK stats:
#   Earnings Growth: 0.583
#   Beta: 0.861
#   Shares Outstanding: 142424000
# ----------------------------------------
# VRSN stats:
#   Earnings Growth: 0.125
#   Beta: 0.904
#   Shares Outstanding: 97600000
# ----------------------------------------
# VRTX stats:
#   Earnings Growth: None
#   Beta: 0.402
#   Shares Outstanding: 258102000
# ----------------------------------------
# VZ stats:
#   Earnings Growth: -0.009
#   Beta: 0.411
#   Shares Outstanding: 4209520128
# ----------------------------------------
# WBD stats:
#   Earnings Growth: None
#   Beta: 1.487
#   Shares Outstanding: 2451909888
# ----------------------------------------
# WDAY stats:
#   Earnings Growth: 0.661
#   Beta: 1.344
#   Shares Outstanding: 213000000
# ----------------------------------------
# WDC stats:
#   Earnings Growth: None
#   Beta: 1.381
#   Shares Outstanding: 343452000
# ----------------------------------------
# WMB stats:
#   Earnings Growth: -0.129
#   Beta: 1.077
#   Shares Outstanding: 1218930048
# ----------------------------------------
# XEL stats:
#   Earnings Growth: 0.038
#   Beta: 0.4
#   Shares Outstanding: 557500992
# ----------------------------------------
# XOM stats:
#   Earnings Growth: 0.104
#   Beta: 0.877
#   Shares Outstanding: 4442829824
# ----------------------------------------
# ZBRA stats:
#   Earnings Growth: -0.219
#   Beta: 1.658
#   Shares Outstanding: 51580400
# ----------------------------------------
# ZS stats:
#   Earnings Growth: None
#   Beta: 0.814
#   Shares Outstanding: 152490000
# ----------------------------------------
# William O'Neil selected stocks: ['AMD', 'DVN', 'FANG', 'MELI', 'MRO', 'NVDA', 'OKE', 'OXY', 'PLTR']

# %%
def larry_hite_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock_data = data['Close'][ticker]
        new_high = stock_data.max()  # Check if it's at a new high
        
        if stock_data[-1] == new_high:  # Stock is at its highest point in its history
            selected_stocks.append(ticker)
    
    return selected_stocks

larry_hite_stocks = larry_hite_selection(data)
print("Larry Hite selected stocks:", larry_hite_stocks)
# Out:
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/1579398852.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if stock_data[-1] == new_high:  # Stock is at its highest point in its history
# Larry Hite selected stocks: ['ORCL', 'IBM', 'ANET', 'PLTR', 'MSI', 'FICO', 'TMUS', 'TRGP', 'ADP', 'ORLY', 'TTD']

# %%
def ed_seykota_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock_data = data['Close'][ticker]
        ma_100 = stock_data.rolling(window=100).mean()
        
        if stock_data[-1] > ma_100[-1]:  # Trend-following condition, price is above 100-day MA
            selected_stocks.append(ticker)
    
    return selected_stocks

ed_seykota_stocks = ed_seykota_selection(data)
print("Ed Seykota selected stocks:", ed_seykota_stocks)
# Out:
# Ed Seykota selected stocks: ['AAPL', 'NVDA', 'AVGO', 'CRM', 'AMD', 'ORCL', 'ACN', 'CSCO', 'IBM', 'NOW', 'TXN', 'PANW', 'ADI', 'ANET', 'PLTR', 'MSI', 'ADSK', 'FTNT', 'FICO', 'MPWR', 'IT', 'CTSH', 'HPQ', 'GLW', 'CDW', 'ANSS', 'HPE', 'KEYS', 'NTAP', 'TYL', 'STX', 'GDDY', 'PTC', 'TDY', 'ZBRA', 'VRSN', 'AKAM', 'TRMB', 'GEN', 'JBL', 'FFIV', 'JNPR', 'EPAM', 'META', 'NFLX', 'TMUS', 'CMCSA', 'T', 'VZ', 'EA', 'CHTR', 'OMC', 'LYV', 'IPG', 'MTCH', 'FOXA', 'FOX', 'XOM', 'EOG', 'WMB', 'OKE', 'KMI', 'BKR', 'FANG', 'TRGP', 'EQT', 'MRO', 'TSLA', 'COST', 'LIN', 'ISRG', 'BKNG', 'HON', 'ADP', 'SBUX', 'GILD', 'PDD', 'MELI', 'MDLZ', 'CEG', 'CTAS', 'PYPL', 'MAR', 'ORLY', 'CSX', 'MRVL', 'DASH', 'PCAR', 'AEP', 'CPRT', 'WDAY', 'TTD', 'PAYX', 'KDP', 'KHC', 'ODFL', 'FAST', 'EXC', 'DDOG', 'VRSK', 'EA', 'BKR', 'CTSH', 'FANG', 'CCEP', 'XEL', 'CDW', 'ANSS', 'TEAM', 'ILMN']
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/1168215537.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if stock_data[-1] > ma_100[-1]:  # Trend-following condition, price is above 100-day MA

# %%
def gary_bielfeldt_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock_data = data['Close'][ticker]
        relative_strength = stock_data[-1] / stock_data.mean()  # Simplified relative strength calculation
        
        if relative_strength > 1.2:  # If the stock is performing at least 20% better than its average
            selected_stocks.append(ticker)
    
    return selected_stocks

gary_bielfeldt_stocks = gary_bielfeldt_selection(data)
print("Gary Bielfeldt selected stocks:", gary_bielfeldt_stocks)
# Out:
# Gary Bielfeldt selected stocks: ['AAPL', 'NVDA', 'MSFT', 'AVGO', 'CRM', 'AMD', 'ORCL', 'ACN', 'IBM', 'NOW', 'QCOM', 'TXN', 'INTU', 'AMAT', 'PANW', 'ADI', 'MU', 'LRCX', 'KLAC', 'ANET', 'PLTR', 'SNPS', 'APH', 'MSI', 'CDNS', 'CRWD', 'NXPI', 'ROP', 'FTNT', 'FICO', 'MPWR', 'IT', 'HPQ', 'DELL', 'GLW', 'ON', 'CDW', 'HPE', 'NTAP', 'TYL', 'FSLR', 'SMCI', 'STX', 'GDDY', 'WDC', 'PTC', 'TER', 'GEN', 'JBL', 'FFIV', 'JNPR', 'META', 'GOOGL', 'GOOG', 'NFLX', 'TMUS', 'OMC', 'LYV', 'NWSA', 'FOXA', 'FOX', 'NWS', 'XOM', 'COP', 'EOG', 'WMB', 'PSX', 'OKE', 'MPC', 'KMI', 'VLO', 'HES', 'BKR', 'OXY', 'FANG', 'TRGP', 'EQT', 'MRO', 'AMZN', 'TSLA', 'COST', 'LIN', 'AMGN', 'ISRG', 'BKNG', 'VRTX', 'ADP', 'REGN', 'GILD', 'PDD', 'MELI', 'CEG', 'CTAS', 'ASML', 'MAR', 'ORLY', 'MRVL', 'DASH', 'PCAR', 'CPRT', 'TTD', 'PAYX', 'ROST', 'AZN', 'ODFL', 'FAST', 'DDOG', 'VRSK', 'BKR', 'FANG', 'CCEP', 'ON', 'CDW', 'SMCI']
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/1906018964.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   relative_strength = stock_data[-1] / stock_data.mean()  # Simplified relative strength calculation

# %%
def richard_dennis_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock_data = data['Close'][ticker]
        # Exclude today's closing price by slicing up to -1
        breakout_level = stock_data[-51:-1].max()  # Last 50 days excluding today
        
        if stock_data[-1] > breakout_level:  # Check for breakout condition
            selected_stocks.append(ticker)
    
    return selected_stocks

richard_dennis_stocks = richard_dennis_selection(data)
print("Richard Dennis selected stocks:", richard_dennis_stocks)
# Out:
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/1427080975.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if stock_data[-1] > breakout_level:  # Check for breakout condition
# Richard Dennis selected stocks: ['NVDA', 'AVGO', 'CRM', 'AMD', 'ORCL', 'IBM', 'ANET', 'PLTR', 'MSI', 'FICO', 'HPE', 'TMUS', 'LYV', 'TRGP', 'ADP', 'GILD', 'PYPL', 'MAR', 'ORLY', 'CPRT', 'TTD', 'DDOG']

# %%
def bruce_kovner_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock = yf.Ticker(ticker)
        stock_data = data['Close'][ticker]
        earnings_growth = stock.info.get("earningsGrowth", None)
        # Exclude the last data point in the breakout_level calculation
        breakout_level = stock_data[-51:-1].max()
        
        if (earnings_growth is not None and earnings_growth > 0.1 and
            stock_data[-1] > breakout_level):  # Stock breaking out with positive earnings growth
            selected_stocks.append(ticker)
    
    return selected_stocks

bruce_kovner_stocks = bruce_kovner_selection(data)
print("Bruce Kovner selected stocks:", bruce_kovner_stocks)
# Out:
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/3718343196.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   stock_data[-1] > breakout_level):  # Stock breaking out with positive earnings growth
# Bruce Kovner selected stocks: ['NVDA', 'AVGO', 'CRM', 'AMD', 'ORCL', 'IBM', 'ANET', 'PLTR', 'MSI', 'TMUS', 'GILD', 'PYPL', 'MAR', 'TTD']

# %%
def michael_marcus_selection(data):
    selected_stocks = []
    
    for ticker in tickers:
        stock_data = data['Close'][ticker]
        ma_100 = stock_data.rolling(window=100).mean()
        
        if stock_data[-1] > ma_100[-1]:  # Trend-following condition
            selected_stocks.append(ticker)
    
    return selected_stocks

michael_marcus_stocks = michael_marcus_selection(data)
print("Michael Marcus selected stocks:", michael_marcus_stocks)
# Out:
# Michael Marcus selected stocks: ['AAPL', 'NVDA', 'AVGO', 'CRM', 'AMD', 'ORCL', 'ACN', 'CSCO', 'IBM', 'NOW', 'TXN', 'PANW', 'ADI', 'ANET', 'PLTR', 'MSI', 'ADSK', 'FTNT', 'FICO', 'MPWR', 'IT', 'CTSH', 'HPQ', 'GLW', 'CDW', 'ANSS', 'HPE', 'KEYS', 'NTAP', 'TYL', 'STX', 'GDDY', 'PTC', 'TDY', 'ZBRA', 'VRSN', 'AKAM', 'TRMB', 'GEN', 'JBL', 'FFIV', 'JNPR', 'EPAM', 'META', 'NFLX', 'TMUS', 'CMCSA', 'T', 'VZ', 'EA', 'CHTR', 'OMC', 'LYV', 'IPG', 'MTCH', 'FOXA', 'FOX', 'XOM', 'EOG', 'WMB', 'OKE', 'KMI', 'BKR', 'FANG', 'TRGP', 'EQT', 'MRO', 'TSLA', 'COST', 'LIN', 'ISRG', 'BKNG', 'HON', 'ADP', 'SBUX', 'GILD', 'PDD', 'MELI', 'MDLZ', 'CEG', 'CTAS', 'PYPL', 'MAR', 'ORLY', 'CSX', 'MRVL', 'DASH', 'PCAR', 'AEP', 'CPRT', 'WDAY', 'TTD', 'PAYX', 'KDP', 'KHC', 'ODFL', 'FAST', 'EXC', 'DDOG', 'VRSK', 'EA', 'BKR', 'CTSH', 'FANG', 'CCEP', 'XEL', 'CDW', 'ANSS', 'TEAM', 'ILMN']
# /var/folders/m6/wxc9fp790875bb7z5jw_q5c80000gn/T/ipykernel_86969/350309957.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if stock_data[-1] > ma_100[-1]:  # Trend-following condition

# %%
# Combine results
portfolio = {
    "Paul Tudor Jones": paul_tudor_jones_stocks,
    "Benjamin Graham": benjamin_graham_stocks,
    "Goldman Sachs": goldman_sachs_stocks,
    "bridgewater stocks": bridgewater_stocks,
     "ARK Invest": ark_invest_stocks,
    "Marty Schwartz": marty_schwartz_stocks,
    "David Ryan": david_ryan_stocks,
    "William O'Neil": william_oneil_stocks,
    "Larry Hite": larry_hite_stocks,
    "Ed Seykota": ed_seykota_stocks,
    "Gary Bielfeldt": gary_bielfeldt_stocks,
    "Richard Dennis": richard_dennis_stocks,
    "Bruce Kovner": bruce_kovner_stocks,
    "Michael Marcus": michael_marcus_stocks
}

# Convert to DataFrame for easy viewing
portfolio_df = pd.DataFrame.from_dict(portfolio, orient="index").transpose()
portfolio_df
# Out:
#     Paul Tudor Jones Benjamin Graham Goldman Sachs bridgewater stocks  \
# 0               AAPL            FANG           MRO               AAPL
# 1               NVDA            None          None               NVDA
# 2               AVGO            None          None               MSFT
# 3                CRM            None          None               AVGO
# 4                AMD            None          None                CRM
# ..               ...             ...           ...                ...
# 110             None            None          None               FANG
# 111             None            None          None               CCEP
# 112             None            None          None                XEL
# 113             None            None          None               SMCI
# 114             None            None          None                ARM
#
#     ARK Invest Marty Schwartz David Ryan William O'Neil Larry Hite Ed Seykota  \
# 0         AAPL           AAPL       TZOO            AMD       ORCL       AAPL
# 1         NVDA           NVDA       TASK            DVN        IBM       NVDA
# 2         MSFT           AVGO       ALTS           FANG       ANET       AVGO
# 3         AVGO            CRM       None           MELI       PLTR        CRM
# 4         ORCL            AMD       None            MRO        MSI        AMD
# ..         ...            ...        ...            ...        ...        ...
# 110       None           None       None           None       None       None
# 111       None           None       None           None       None       None
# 112       None           None       None           None       None       None
# 113       None           None       None           None       None       None
# 114       None           None       None           None       None       None
#
#     Gary Bielfeldt Richard Dennis Bruce Kovner Michael Marcus
# 0             AAPL           NVDA         NVDA           AAPL
# 1             NVDA           AVGO         AVGO           NVDA
# 2             MSFT            CRM          CRM           AVGO
# 3             AVGO            AMD          AMD            CRM
# 4              CRM           ORCL         ORCL            AMD
# ..             ...            ...          ...            ...
# 110           CCEP           None         None           None
# 111             ON           None         None           None
# 112            CDW           None         None           None
# 113           SMCI           None         None           None
# 114           None           None         None           None
#
# [115 rows x 14 columns]

# %%
from collections import Counter

# Flatten the portfolio dictionary into a single list of tickers
all_tickers = []
for stocks in portfolio.values():
    all_tickers.extend(stocks)

# Count the occurrences of each ticker
ticker_counts = Counter(all_tickers)

# Convert the counts to a sorted DataFrame
ticker_ranked_df = pd.DataFrame(ticker_counts.items(), columns=["Ticker", "Count"]).sort_values(by="Count", ascending=False)

# Display the ranked tickers
ticker_ranked_df.reset_index(drop=True, inplace=True)
print(ticker_ranked_df)
# Out:
#     Ticker  Count
# 0     FANG     16
# 1     CTSH     12
# 2      BKR     12
# 3     PLTR     11
# 4      TTD     10
# ..     ...    ...
# 151    SLB      1
# 152   ADBE      1
# 153    ARM      1
# 154   GEHC      1
# 155    VLO      1
#
# [156 rows x 2 columns]

# %%
#import yahooquery as yq
#import pandas as pd

#fund = yq.Ticker('xlf')
#fund.fund_holding_info.keys()
#dict_keys(['hasgx'])

#df = pd.DataFrame(fund.fund_holding_info['xlf']['holdings'])

#df

# %% [markdown]
# @AliCodesJava @WillMo2198
# Here you go:
#
# from lxml import html
# import requests
# from collections import OrderedDict
#
# class ticker_data_object:
#
# '''
# Instantiation of ticker_data_object will set attributes and assign their value(s) from the URL response keys and values
# stored to ticker data dictionary passed while using valid attribute names mapped in ticker_data_translator dictionary
# to keys retrieved from URL response
# '''
# def __init__(self, data=None):
#     if data is not None:
#         for key, value in data.items():
#             attribute = [translator_value for translator_key, translator_value in ticker_data_translator.items() if key.startswith(translator_key) == True][0]
#             setattr(self, attribute, value)
# def get_ticker_data_translator():
#
# '''
# Map valid attribute names to use for each key retrived from the URL response
#
# NOTE: Keys below are substrings used to locate actual key names restrieved from URL responses
#       some of which may terminate with dynamic info such as a specifica date
#
# '''
# return {
#         'Current Price': 'current_price',
#         'Previous Close': 'previous_close',
#         'Open': 'open_price',
#         'Bid': 'bid',
#         'Ask': 'ask',
#         'Day\'s Range': 'days_range',
#         '52 Week Range': 'fifty_two_week_range',
#         'Volume': 'volume',
#         'Avg. Volume': 'avg_volume',
#         'Market Cap': 'market_cap',
#         'Beta (5Y Monthly)': 'beta_5y_monthly',
#         'PE Ratio (TTM)': 'pe_ratio_ttm',
#         'EPS (TTM)': 'eps_ttm',
#         'Earnings Date': 'earnings_date',
#         'Forward Dividend & Yield': 'forward_dividend_and_yield',
#         'Ex-Dividend Date': 'ex_dividend_date',
#         '1y Target Est': 'one_year_target_est',
#         'Market Cap (intraday)': 'market_cap_intraday',
#         'Enterprise Value': 'enterprise_value',
#         'Trailing P/E': 'trailing_pe',
#         'Forward P/E': 'forward_pe',
#         'PEG Ratio (5 yr expected)': 'peg_ratio_5_yr_expected',
#         'Price/Sales (ttm)': 'price_to_sales_ttm',
#         'Price/Book (mrq)': 'price_to_book_mrq',
#         'Enterprise Value/Revenue': 'enterprise_value_to_revenue',
#         'Enterprise Value/EBITDA': 'enterprise_value_to_revenue',
#         '52-Week Change': 'fifty_two_week_change',
#         'S&P500 52-Week Change': 'sp500_52_wee_change',
#         '52 Week High': 'fifty_two_week_high',
#         '52 Week Low': 'fifty_two_week_low',
#         '50-Day Moving Average': 'fifty_day_average',
#         '200-Day Moving Average': 'two_hundred_day_moving_average',
#         'Avg Vol (3 month)': 'avg_vol_3_month',
#         'Avg Vol (10 day)': 'avg_vol_10_day',
#         'Shares Outstanding': 'shares_outstanding',
#         'Implied Shares Outstanding': 'implied_shares_oustanding',
#         'Float': 'float_amount',
#         '% Held by Insiders': 'percentage_held_by_insiders',
#         '% Held by Institutions': 'percentage_held_by_institutions',
#         'Shares Short': 'shares_short',
#         'Short Ratio': 'short_ratio',
#         'Short % of Float': 'short_percentage_of_float',
#         'Short % of Shares Outstanding': 'short_percentage_of_shares_outstanding',
#         'Shares Short (prior month': 'shares_short_prior_month',
#         'Forward Annual Dividend Rate': 'forward_annual_dividend_rate',
#         'Forward Annual Dividend Yield': 'forward_annual_dividend_yield',
#         'Trailing Annual Dividend Rate': 'trailing_annual_dividend_rate',
#         'Trailing Annual Dividend Yield': 'trailing_annual_dividend_yield',
#         '5 Year Average Dividend Yield': 'five_year_average_dividend_yield',
#         'Payout Ratio': 'payout_ratio',
#         'Dividend Date': 'dividend_date',
#         'Ex-Dividend Date': 'ex_dividend_date',
#         'Last Split Factor': 'last_split_factor',
#         'Last Split Date': 'last_split_date',
#         'Fiscal Year Ends': 'fiscal_year_ends',
#         'Most Recent Quarter (mrq)': 'most_recent_quarter_mrq',
#         'Profit Margin': 'profit_margin',
#         'Operating Margin (ttm)': 'operating_margin_ttm',
#         'Return on Assets (ttm)': 'return_on_assets_ttm',
#         'Return on Equity (ttm)': 'return_on_equity_ttm',
#         'Revenue (ttm)': 'revenue_ttm',
#         'Revenue Per Share (ttm)': 'revenue_per_share_ttm',
#         'Quarterly Revenue Growth (yoy)': 'quarterly_revenue_growth_yoy',
#         'Gross Profit (ttm)': 'gross_profit_ttm',
#         'EBITDA': 'ebitda',
#         'Net Income Avi to Common (ttm)': 'net_income_avi_to_common_ttm',
#         'Diluted EPS (ttm)': 'diluted_eps_ttm',
#         'Quarterly Earnings Growth (yoy)': 'quarterly_earnings_growth_yoy',
#         'Total Cash (mrq)': 'total_cash_mrq',
#         'Total Cash Per Share (mrq)': 'total_cash_per_share_mrq',
#         'Total Debt (mrq)': 'total_debt_mrq',
#         'Total Debt/Equity (mrq)': 'total_debt_to_equity_mrq',
#         'Current Ratio (mrq)': 'current_ratio_mrq',
#         'Book Value Per Share (mrq)': 'book_value_per_share_mrq',
#         'Operating Cash Flow (ttm)': 'operating_cash_flow_ttm',
#         'Levered Free Cash Flow (ttm)': 'levered_free_cash_flow_ttm',
#         'Ticker': 'ticker'
#         }
# def get_ticker_data(ticker):
# http_headers = {"accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,/;q=0.8,application/signed-exchange;v=b3;q=0.9",
# "accept-encoding": "gzip, deflate, br",
# "accept-language": "en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7",
# "cache-control": "max-age=0",
# "dnt": "1",
# "sec-fetch-dest": "document",
# "sec-fetch-mode": "navigate",
# "sec-fetch-site": "none",
# "sec-fetch-user": "?1",
# "upgrade-insecure-requests": "1",
# "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.122 Safari/537.36"}
#
# # GET & Parse Response from Summary URL to ticker_data dictionary
# summary_url = "https://finance.yahoo.com/quote/%s?p=%s" % (ticker, ticker)
# summary_response = requests.get(summary_url, verify=True, headers=http_headers, timeout=30)
# summary_parser = html.fromstring(summary_response.text)
# current_price = summary_parser.xpath('//*[@id="quote-header-info"]/div[3]/div[1]/div[1]/fin-streamer[1]/text()')
# summary_table = summary_parser.xpath('//div[contains(@data-test,"summary-table")]//tr')
# ticker_data = OrderedDict()
# ticker_data.update({'Current Price': current_price[0]})
# for table_data in summary_table:
#     raw_table_key = table_data.xpath('.//td[1]//text()')
#     raw_table_value = table_data.xpath('.//td[2]//text()')
#     table_key = ''.join(raw_table_key).strip()
#     table_value = ''.join(raw_table_value).strip()
#     ticker_data.update({table_key: table_value})
#
# # GET & Parse Response from Statistics URL to ticker_data dictionary
# statistics_url = "https://finance.yahoo.com/quote/%s/key-statistics?p=%s" % (ticker, ticker)
# statistics_response = requests.get(statistics_url, verify=True, headers=http_headers, timeout=30)
# statistics_parser = html.fromstring(statistics_response.text)
# statistics_table = statistics_parser.xpath('//div[contains(@class,"Mstart(a) Mend(a)")]//tr')
# for table_data in statistics_table:
#     raw_table_key = table_data.xpath('.//td[1]//text()')
#     raw_table_value = table_data.xpath('.//td[2]//text()')
#     table_key = ''.join(raw_table_key).strip()
#     table_value = ''.join(raw_table_value).strip()
#     ticker_data.update({table_key: table_value})
#
# # Add Ticker key to ticker_data dictionary
# ticker_data.update({'Ticker': ticker})
#
# # Return TickerData object from ticker_data disctionary
# return ticker_data_object(ticker_data)
# if name == "main":
#
# # Get ticker_data_translator dictionary
# ticker_data_translator = get_ticker_data_translator()
#
# stock_tickers_list = ['GOOGL', 'AMZN', 'AAPL', 'META', 'MSFT', 'NVDA', 'TSLA']
#
# for stock_ticker in stock_tickers_list:
#     ticker_data = get_ticker_data(stock_ticker)
#     print(ticker_data.ticker + " current price: " + ticker_data.current_price)
